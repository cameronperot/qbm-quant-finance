# %% [markdown]
# # QBM Comparison Exact vs. Annealer

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext autotime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import neptune.new as neptune
from numba import njit
from scipy.constants import k as k_B, h as h_P

k_B /= h_P * 1e9

from qbm.models import BQRBM
from qbm.plotting import plot_qq
from qbm.utils import (
    binarize_df,
    convert_bin_list_to_str,
    get_binarization_params,
    get_project_dir,
    get_rng,
    kl_divergence,
    load_artifact,
    lr_exp_decay,
    prepare_training_data,
    save_artifact,
    unbinarize_df,
)
from qbm.utils.exact_qbm import get_pauli_kron, compute_H, compute_rho

# configure directories
project_dir = get_project_dir()
artifact_dir = project_dir / "artifacts/qbm/8x4"
if not artifact_dir.exists():
    artifact_dir.mkdir(parents=True)
plot_dir = project_dir / "results/plots/qbm/8x4"
if not plot_dir.exists():
    plot_dir.mkdir(parents=True)
    
# load anneal schedule
df_anneal = pd.read_csv(
    project_dir
    / "data/anneal_schedules/csv/09-1265A-A_Advantage_system5_1_annealing_schedule.csv",
    index_col="s",
)
if 0.5 not in df_anneal.index:
    df_anneal.loc[0.5] = (df_anneal.loc[0.499] + df_anneal.loc[0.501]) / 2
# Out:
# time: 1.84 s (started: 2022-01-29 21:07:22 +01:00)

# %% [markdown]
# ## Train Data Creation

# %%
seed = 42
n_visible = 8
n_hidden = 4
n_qubits = n_visible + n_hidden

rng = get_rng(seed)
n_samples = 1500
α = 2 / 3
N_1 = rng.normal(-2, 1, int(round(n_samples * α, 0)))
N_2 = rng.normal(3, 1, int(round(n_samples * (1 - α), 0)))
x = np.concatenate((N_1, N_2))

df = pd.DataFrame.from_dict({"x": x})
binarization_params = get_binarization_params(df, n_bits=n_visible)
df_binarized = binarize_df(df, binarization_params)
X_train = prepare_training_data(df_binarized)["X_train"]
# Out:
# time: 11.2 ms (started: 2022-01-29 21:07:24 +01:00)

# %%
def callback(model, sample_state_vectors):
    X_train = model.X_train
    n_visible = model.X_train.shape[1]
    train_states = (
        model._eigen_to_binary(model.X_train) * 2.0 ** np.arange(n_visible - 1, -1, -1)
    ).sum(axis=1)
    sample_states = (
        model._eigen_to_binary(sample_state_vectors[:, :n_visible])
        * 2.0 ** np.arange(n_visible - 1, -1, -1)
    ).sum(axis=1)

    dkl = kl_divergence(train_states, sample_states, n_bins=32)

    return {"value": dkl, "print": f"D_KL = {dkl:.3f}"}
# Out:
# time: 1.14 ms (started: 2022-01-29 21:07:24 +01:00)

# %% [markdown]
# ## Model Analysis (Exact)

# %%
# model params
s = 1.0
embedding = None
beta_initial = 0.5
exact_params = {"beta": 0.5}

# training params
n_epochs = 100
n_samples = 10_000
learning_rate = 0.1
decay_epoch = 50
decay_period = 10
epochs = np.arange(1, n_epochs + 1)
learning_rates = learning_rate * lr_exp_decay(epochs, decay_epoch=50, period=10)
learning_rates_beta = learning_rate * lr_exp_decay(epochs, decay_epoch=50, period=20)

anneal_params = {
    "s": s,
    "A": df_anneal.loc[s, "A(s) (GHz)"],
    "B": df_anneal.loc[s, "B(s) (GHz)"],
}

train_models = True
models_dir = artifact_dir / f"models/mini_batch_comparison"
mini_batch_sizes = [10, 16, 32, 64, 100, 128]
for mini_batch_size in mini_batch_sizes:
    if train_models:
        # model init
        model_exact = BQRBM(
            X_train=X_train,
            n_hidden=n_hidden,
            embedding=embedding,
            anneal_params=anneal_params,
            beta_initial=beta_initial,
            exact_params=exact_params,
        )

        # model train and save
        model_exact.train(
            n_epochs=n_epochs,
            n_samples=n_samples,
            learning_rate=learning_rates,
            learning_rate_beta=learning_rates_beta,
            mini_batch_size=mini_batch_size,
            callback=callback,
        )
        model_exact.save(models_dir / f"model_exact-s={s}-mbs={mini_batch_size}.pkl")
        model_exact_metrics = {
            "A": model_exact.A,
            "B": model_exact.B,
            "a": model_exact.a,
            "b": model_exact.b,
            "W": model_exact.W,
            "beta": model_exact.beta,
            "embedding": model_exact.embedding,
            "anneal_params": model_exact.anneal_params,
            "exact_params": model_exact.exact_params,
            "beta_history": model_exact.beta_history,
            "callback_outputs": [x for x in model_exact.callback_outputs],
        }
        save_artifact(
            model_exact_metrics,
            models_dir / f"model_exact-s={s}-mbs={mini_batch_size}-attributes.pkl",
        )

model_paths = [x for x in models_dir.iterdir() if "attributes" not in str(x)]
models = {}
for model_path in model_paths:
    mbs = int([x for x in model_path.stem.split("-") if "mbs" in x][0].split("=")[1])
    models[mbs] = BQRBM.load(model_path)
# Out:
# [BQRBM] epoch 1: β = 0.481, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.618640
# 	D_KL = 0.190
# [BQRBM] epoch 2: β = 0.468, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.596006
# 	D_KL = 0.092
# [BQRBM] epoch 3: β = 0.462, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.580453
# 	D_KL = 0.065
# [BQRBM] epoch 4: β = 0.464, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.610706
# 	D_KL = 0.047
# [BQRBM] epoch 5: β = 0.468, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.578613
# 	D_KL = 0.054
# [BQRBM] epoch 6: β = 0.473, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.597837
# 	D_KL = 0.055
# [BQRBM] epoch 7: β = 0.477, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.585692
# 	D_KL = 0.046
# [BQRBM] epoch 8: β = 0.480, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.592885
# 	D_KL = 0.042
# [BQRBM] epoch 9: β = 0.484, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.602927
# 	D_KL = 0.043
# [BQRBM] epoch 10: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.588409
# 	D_KL = 0.056
# [BQRBM] epoch 11: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.609372
# 	D_KL = 0.035
# [BQRBM] epoch 12: β = 0.491, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.582401
# 	D_KL = 0.043
# [BQRBM] epoch 13: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.602642
# 	D_KL = 0.042
# [BQRBM] epoch 14: β = 0.486, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.582420
# 	D_KL = 0.032
# [BQRBM] epoch 15: β = 0.487, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.598584
# 	D_KL = 0.028
# [BQRBM] epoch 16: β = 0.488, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.593440
# 	D_KL = 0.029
# [BQRBM] epoch 17: β = 0.491, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.618776
# 	D_KL = 0.030
# [BQRBM] epoch 18: β = 0.491, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.598964
# 	D_KL = 0.027
# [BQRBM] epoch 19: β = 0.491, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.597223
# 	D_KL = 0.024
# [BQRBM] epoch 20: β = 0.496, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.594518
# 	D_KL = 0.030
# [BQRBM] epoch 21: β = 0.496, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.580769
# 	D_KL = 0.023
# [BQRBM] epoch 22: β = 0.494, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.606045
# 	D_KL = 0.019
# [BQRBM] epoch 23: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.582284
# 	D_KL = 0.027
# [BQRBM] epoch 24: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.602517
# 	D_KL = 0.023
# [BQRBM] epoch 25: β = 0.491, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.583113
# 	D_KL = 0.019
# [BQRBM] epoch 26: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.579815
# 	D_KL = 0.022
# [BQRBM] epoch 27: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.605594
# 	D_KL = 0.022
# [BQRBM] epoch 28: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.584183
# 	D_KL = 0.019
# [BQRBM] epoch 29: β = 0.493, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.589859
# 	D_KL = 0.020
# [BQRBM] epoch 30: β = 0.494, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.597071
# 	D_KL = 0.020
# [BQRBM] epoch 31: β = 0.496, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.579529
# 	D_KL = 0.018
# [BQRBM] epoch 32: β = 0.498, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.592773
# 	D_KL = 0.018
# [BQRBM] epoch 33: β = 0.494, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.593032
# 	D_KL = 0.022
# [BQRBM] epoch 34: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.581387
# 	D_KL = 0.018
# [BQRBM] epoch 35: β = 0.492, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.609447
# 	D_KL = 0.019
# [BQRBM] epoch 36: β = 0.492, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.582923
# 	D_KL = 0.022
# [BQRBM] epoch 37: β = 0.488, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.609088
# 	D_KL = 0.017
# [BQRBM] epoch 38: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.583414
# 	D_KL = 0.014
# [BQRBM] epoch 39: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.590843
# 	D_KL = 0.018
# [BQRBM] epoch 40: β = 0.495, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.295809
# 	D_KL = 0.016
# [BQRBM] epoch 41: β = 0.494, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.282037
# 	D_KL = 0.014
# [BQRBM] epoch 42: β = 0.497, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.355469
# 	D_KL = 0.020
# [BQRBM] epoch 43: β = 0.495, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.278000
# 	D_KL = 0.012
# [BQRBM] epoch 44: β = 0.495, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.284834
# 	D_KL = 0.015
# [BQRBM] epoch 45: β = 0.497, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.283370
# 	D_KL = 0.014
# [BQRBM] epoch 46: β = 0.494, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.277047
# 	D_KL = 0.017
# [BQRBM] epoch 47: β = 0.496, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.293464
# 	D_KL = 0.012
# [BQRBM] epoch 48: β = 0.498, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.279195
# 	D_KL = 0.015
# [BQRBM] epoch 49: β = 0.501, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.290408
# 	D_KL = 0.014
# [BQRBM] epoch 50: β = 0.504, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:02.286087
# 	D_KL = 0.015
# [BQRBM] epoch 51: β = 0.502, learning rate = 9.33e-02, β learning rate = 9.66e-02, epoch duration = 0:00:02.289387
# 	D_KL = 0.009
# [BQRBM] epoch 52: β = 0.497, learning rate = 8.71e-02, β learning rate = 9.33e-02, epoch duration = 0:00:02.281004
# 	D_KL = 0.009
# [BQRBM] epoch 53: β = 0.494, learning rate = 8.12e-02, β learning rate = 9.01e-02, epoch duration = 0:00:02.282586
# 	D_KL = 0.012
# [BQRBM] epoch 54: β = 0.494, learning rate = 7.58e-02, β learning rate = 8.71e-02, epoch duration = 0:00:02.284866
# 	D_KL = 0.011
# [BQRBM] epoch 55: β = 0.494, learning rate = 7.07e-02, β learning rate = 8.41e-02, epoch duration = 0:00:02.283077
# 	D_KL = 0.015
# [BQRBM] epoch 56: β = 0.495, learning rate = 6.60e-02, β learning rate = 8.12e-02, epoch duration = 0:00:02.285777
# 	D_KL = 0.012
# [BQRBM] epoch 57: β = 0.495, learning rate = 6.16e-02, β learning rate = 7.85e-02, epoch duration = 0:00:02.386441
# 	D_KL = 0.009
# [BQRBM] epoch 58: β = 0.497, learning rate = 5.74e-02, β learning rate = 7.58e-02, epoch duration = 0:00:02.421827
# 	D_KL = 0.011
# [BQRBM] epoch 59: β = 0.496, learning rate = 5.36e-02, β learning rate = 7.32e-02, epoch duration = 0:00:02.286577
# 	D_KL = 0.012
# [BQRBM] epoch 60: β = 0.496, learning rate = 5.00e-02, β learning rate = 7.07e-02, epoch duration = 0:00:02.273460
# 	D_KL = 0.013
# [BQRBM] epoch 61: β = 0.497, learning rate = 4.67e-02, β learning rate = 6.83e-02, epoch duration = 0:00:02.286501
# 	D_KL = 0.012
# [BQRBM] epoch 62: β = 0.499, learning rate = 4.35e-02, β learning rate = 6.60e-02, epoch duration = 0:00:02.277509
# 	D_KL = 0.010
# [BQRBM] epoch 63: β = 0.498, learning rate = 4.06e-02, β learning rate = 6.37e-02, epoch duration = 0:00:02.287485
# 	D_KL = 0.011
# [BQRBM] epoch 64: β = 0.498, learning rate = 3.79e-02, β learning rate = 6.16e-02, epoch duration = 0:00:02.280900
# 	D_KL = 0.011
# [BQRBM] epoch 65: β = 0.498, learning rate = 3.54e-02, β learning rate = 5.95e-02, epoch duration = 0:00:02.278177
# 	D_KL = 0.011
# [BQRBM] epoch 66: β = 0.499, learning rate = 3.30e-02, β learning rate = 5.74e-02, epoch duration = 0:00:02.286857
# 	D_KL = 0.008
# [BQRBM] epoch 67: β = 0.499, learning rate = 3.08e-02, β learning rate = 5.55e-02, epoch duration = 0:00:02.276253
# 	D_KL = 0.010
# [BQRBM] epoch 68: β = 0.499, learning rate = 2.87e-02, β learning rate = 5.36e-02, epoch duration = 0:00:02.288327
# 	D_KL = 0.009
# [BQRBM] epoch 69: β = 0.498, learning rate = 2.68e-02, β learning rate = 5.18e-02, epoch duration = 0:00:02.329566
# 	D_KL = 0.012
# [BQRBM] epoch 70: β = 0.497, learning rate = 2.50e-02, β learning rate = 5.00e-02, epoch duration = 0:00:02.306841
# 	D_KL = 0.007
# [BQRBM] epoch 71: β = 0.497, learning rate = 2.33e-02, β learning rate = 4.83e-02, epoch duration = 0:00:02.281957
# 	D_KL = 0.007
# [BQRBM] epoch 72: β = 0.497, learning rate = 2.18e-02, β learning rate = 4.67e-02, epoch duration = 0:00:02.276787
# 	D_KL = 0.010
# [BQRBM] epoch 73: β = 0.496, learning rate = 2.03e-02, β learning rate = 4.51e-02, epoch duration = 0:00:02.293766
# 	D_KL = 0.009
# [BQRBM] epoch 74: β = 0.497, learning rate = 1.89e-02, β learning rate = 4.35e-02, epoch duration = 0:00:02.278150
# 	D_KL = 0.010
# [BQRBM] epoch 75: β = 0.497, learning rate = 1.77e-02, β learning rate = 4.20e-02, epoch duration = 0:00:02.289448
# 	D_KL = 0.010
# [BQRBM] epoch 76: β = 0.497, learning rate = 1.65e-02, β learning rate = 4.06e-02, epoch duration = 0:00:02.281930
# 	D_KL = 0.007
# [BQRBM] epoch 77: β = 0.497, learning rate = 1.54e-02, β learning rate = 3.92e-02, epoch duration = 0:00:02.286609
# 	D_KL = 0.009
# [BQRBM] epoch 78: β = 0.497, learning rate = 1.44e-02, β learning rate = 3.79e-02, epoch duration = 0:00:02.280293
# 	D_KL = 0.008
# [BQRBM] epoch 79: β = 0.497, learning rate = 1.34e-02, β learning rate = 3.66e-02, epoch duration = 0:00:02.280043
# 	D_KL = 0.009
# [BQRBM] epoch 80: β = 0.497, learning rate = 1.25e-02, β learning rate = 3.54e-02, epoch duration = 0:00:02.283486
# 	D_KL = 0.009
# [BQRBM] epoch 81: β = 0.497, learning rate = 1.17e-02, β learning rate = 3.42e-02, epoch duration = 0:00:02.291020
# 	D_KL = 0.008
# [BQRBM] epoch 82: β = 0.496, learning rate = 1.09e-02, β learning rate = 3.30e-02, epoch duration = 0:00:02.288205
# 	D_KL = 0.008
# [BQRBM] epoch 83: β = 0.496, learning rate = 1.02e-02, β learning rate = 3.19e-02, epoch duration = 0:00:02.275273
# 	D_KL = 0.010
# [BQRBM] epoch 84: β = 0.495, learning rate = 9.47e-03, β learning rate = 3.08e-02, epoch duration = 0:00:02.291480
# 	D_KL = 0.007
# [BQRBM] epoch 85: β = 0.496, learning rate = 8.84e-03, β learning rate = 2.97e-02, epoch duration = 0:00:02.274748
# 	D_KL = 0.007
# [BQRBM] epoch 86: β = 0.495, learning rate = 8.25e-03, β learning rate = 2.87e-02, epoch duration = 0:00:02.294266
# 	D_KL = 0.007
# [BQRBM] epoch 87: β = 0.495, learning rate = 7.69e-03, β learning rate = 2.77e-02, epoch duration = 0:00:02.274228
# 	D_KL = 0.010
# [BQRBM] epoch 88: β = 0.495, learning rate = 7.18e-03, β learning rate = 2.68e-02, epoch duration = 0:00:02.453611
# 	D_KL = 0.009
# [BQRBM] epoch 89: β = 0.495, learning rate = 6.70e-03, β learning rate = 2.59e-02, epoch duration = 0:00:02.280430
# 	D_KL = 0.008
# [BQRBM] epoch 90: β = 0.495, learning rate = 6.25e-03, β learning rate = 2.50e-02, epoch duration = 0:00:02.291458
# 	D_KL = 0.008
# [BQRBM] epoch 91: β = 0.495, learning rate = 5.83e-03, β learning rate = 2.41e-02, epoch duration = 0:00:02.281180
# 	D_KL = 0.007
# [BQRBM] epoch 92: β = 0.495, learning rate = 5.44e-03, β learning rate = 2.33e-02, epoch duration = 0:00:02.424364
# 	D_KL = 0.007
# [BQRBM] epoch 93: β = 0.495, learning rate = 5.08e-03, β learning rate = 2.25e-02, epoch duration = 0:00:02.326400
# 	D_KL = 0.009
# [BQRBM] epoch 94: β = 0.495, learning rate = 4.74e-03, β learning rate = 2.18e-02, epoch duration = 0:00:02.276449
# 	D_KL = 0.008
# [BQRBM] epoch 95: β = 0.495, learning rate = 4.42e-03, β learning rate = 2.10e-02, epoch duration = 0:00:02.291034
# 	D_KL = 0.011
# [BQRBM] epoch 96: β = 0.495, learning rate = 4.12e-03, β learning rate = 2.03e-02, epoch duration = 0:00:02.293433
# 	D_KL = 0.006
# [BQRBM] epoch 97: β = 0.494, learning rate = 3.85e-03, β learning rate = 1.96e-02, epoch duration = 0:00:02.344997
# 	D_KL = 0.007
# [BQRBM] epoch 98: β = 0.494, learning rate = 3.59e-03, β learning rate = 1.89e-02, epoch duration = 0:00:02.278342
# 	D_KL = 0.008
# [BQRBM] epoch 99: β = 0.494, learning rate = 3.35e-03, β learning rate = 1.83e-02, epoch duration = 0:00:02.293168
# 	D_KL = 0.007
# [BQRBM] epoch 100: β = 0.494, learning rate = 3.13e-03, β learning rate = 1.77e-02, epoch duration = 0:00:02.274136
# 	D_KL = 0.009
# [BQRBM] epoch 1: β = 0.492, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.435602
# 	D_KL = 0.271
# [BQRBM] epoch 2: β = 0.479, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.446551
# 	D_KL = 0.211
# [BQRBM] epoch 3: β = 0.464, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.438573
# 	D_KL = 0.161
# [BQRBM] epoch 4: β = 0.452, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.447519
# 	D_KL = 0.103
# [BQRBM] epoch 5: β = 0.445, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.438465
# 	D_KL = 0.083
# [BQRBM] epoch 6: β = 0.441, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.446353
# 	D_KL = 0.072
# [BQRBM] epoch 7: β = 0.443, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.435839
# 	D_KL = 0.059
# [BQRBM] epoch 8: β = 0.444, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.450990
# 	D_KL = 0.055
# [BQRBM] epoch 9: β = 0.447, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.435639
# 	D_KL = 0.051
# [BQRBM] epoch 10: β = 0.452, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.452459
# 	D_KL = 0.059
# [BQRBM] epoch 11: β = 0.454, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.442652
# 	D_KL = 0.051
# [BQRBM] epoch 12: β = 0.458, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.444246
# 	D_KL = 0.052
# [BQRBM] epoch 13: β = 0.461, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.443420
# 	D_KL = 0.053
# [BQRBM] epoch 14: β = 0.461, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.439955
# 	D_KL = 0.048
# [BQRBM] epoch 15: β = 0.464, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.435595
# 	D_KL = 0.045
# [BQRBM] epoch 16: β = 0.465, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.450334
# 	D_KL = 0.044
# [BQRBM] epoch 17: β = 0.468, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.439254
# 	D_KL = 0.040
# [BQRBM] epoch 18: β = 0.470, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.585048
# 	D_KL = 0.040
# [BQRBM] epoch 19: β = 0.472, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.533136
# 	D_KL = 0.041
# [BQRBM] epoch 20: β = 0.475, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.441656
# 	D_KL = 0.043
# [BQRBM] epoch 21: β = 0.475, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.445137
# 	D_KL = 0.039
# [BQRBM] epoch 22: β = 0.477, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.443738
# 	D_KL = 0.042
# [BQRBM] epoch 23: β = 0.475, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.596609
# 	D_KL = 0.039
# [BQRBM] epoch 24: β = 0.477, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.453003
# 	D_KL = 0.043
# [BQRBM] epoch 25: β = 0.477, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.446415
# 	D_KL = 0.039
# [BQRBM] epoch 26: β = 0.477, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.447385
# 	D_KL = 0.036
# [BQRBM] epoch 27: β = 0.474, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.440628
# 	D_KL = 0.039
# [BQRBM] epoch 28: β = 0.473, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.442941
# 	D_KL = 0.034
# [BQRBM] epoch 29: β = 0.475, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.444264
# 	D_KL = 0.032
# [BQRBM] epoch 30: β = 0.478, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.446336
# 	D_KL = 0.035
# [BQRBM] epoch 31: β = 0.478, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.438739
# 	D_KL = 0.028
# [BQRBM] epoch 32: β = 0.478, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.448269
# 	D_KL = 0.033
# [BQRBM] epoch 33: β = 0.480, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.457098
# 	D_KL = 0.030
# [BQRBM] epoch 34: β = 0.479, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.449499
# 	D_KL = 0.032
# [BQRBM] epoch 35: β = 0.480, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.434264
# 	D_KL = 0.030
# [BQRBM] epoch 36: β = 0.478, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.451320
# 	D_KL = 0.032
# [BQRBM] epoch 37: β = 0.475, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.444345
# 	D_KL = 0.030
# [BQRBM] epoch 38: β = 0.476, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.506567
# 	D_KL = 0.023
# [BQRBM] epoch 39: β = 0.476, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.454520
# 	D_KL = 0.024
# [BQRBM] epoch 40: β = 0.478, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.437196
# 	D_KL = 0.026
# [BQRBM] epoch 41: β = 0.480, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.454604
# 	D_KL = 0.025
# [BQRBM] epoch 42: β = 0.483, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.436407
# 	D_KL = 0.025
# [BQRBM] epoch 43: β = 0.483, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.455404
# 	D_KL = 0.024
# [BQRBM] epoch 44: β = 0.483, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.438586
# 	D_KL = 0.022
# [BQRBM] epoch 45: β = 0.485, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.453725
# 	D_KL = 0.023
# [BQRBM] epoch 46: β = 0.481, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.432611
# 	D_KL = 0.027
# [BQRBM] epoch 47: β = 0.486, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.450230
# 	D_KL = 0.023
# [BQRBM] epoch 48: β = 0.488, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.438551
# 	D_KL = 0.019
# [BQRBM] epoch 49: β = 0.488, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.451593
# 	D_KL = 0.022
# [BQRBM] epoch 50: β = 0.489, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:01.434515
# 	D_KL = 0.021
# [BQRBM] epoch 51: β = 0.489, learning rate = 9.33e-02, β learning rate = 9.66e-02, epoch duration = 0:00:01.451937
# 	D_KL = 0.021
# [BQRBM] epoch 52: β = 0.486, learning rate = 8.71e-02, β learning rate = 9.33e-02, epoch duration = 0:00:01.442697
# 	D_KL = 0.020
# [BQRBM] epoch 53: β = 0.484, learning rate = 8.12e-02, β learning rate = 9.01e-02, epoch duration = 0:00:01.461300
# 	D_KL = 0.023
# [BQRBM] epoch 54: β = 0.482, learning rate = 7.58e-02, β learning rate = 8.71e-02, epoch duration = 0:00:01.448284
# 	D_KL = 0.021
# [BQRBM] epoch 55: β = 0.482, learning rate = 7.07e-02, β learning rate = 8.41e-02, epoch duration = 0:00:01.439566
# 	D_KL = 0.022
# [BQRBM] epoch 56: β = 0.482, learning rate = 6.60e-02, β learning rate = 8.12e-02, epoch duration = 0:00:01.450699
# 	D_KL = 0.021
# [BQRBM] epoch 57: β = 0.483, learning rate = 6.16e-02, β learning rate = 7.85e-02, epoch duration = 0:00:01.435302
# 	D_KL = 0.019
# [BQRBM] epoch 58: β = 0.484, learning rate = 5.74e-02, β learning rate = 7.58e-02, epoch duration = 0:00:01.453722
# 	D_KL = 0.019
# [BQRBM] epoch 59: β = 0.484, learning rate = 5.36e-02, β learning rate = 7.32e-02, epoch duration = 0:00:01.436578
# 	D_KL = 0.015
# [BQRBM] epoch 60: β = 0.485, learning rate = 5.00e-02, β learning rate = 7.07e-02, epoch duration = 0:00:01.454887
# 	D_KL = 0.020
# [BQRBM] epoch 61: β = 0.486, learning rate = 4.67e-02, β learning rate = 6.83e-02, epoch duration = 0:00:01.435642
# 	D_KL = 0.018
# [BQRBM] epoch 62: β = 0.486, learning rate = 4.35e-02, β learning rate = 6.60e-02, epoch duration = 0:00:01.452574
# 	D_KL = 0.017
# [BQRBM] epoch 63: β = 0.485, learning rate = 4.06e-02, β learning rate = 6.37e-02, epoch duration = 0:00:01.435336
# 	D_KL = 0.015
# [BQRBM] epoch 64: β = 0.485, learning rate = 3.79e-02, β learning rate = 6.16e-02, epoch duration = 0:00:01.452178
# 	D_KL = 0.023
# [BQRBM] epoch 65: β = 0.483, learning rate = 3.54e-02, β learning rate = 5.95e-02, epoch duration = 0:00:01.437109
# 	D_KL = 0.022
# [BQRBM] epoch 66: β = 0.485, learning rate = 3.30e-02, β learning rate = 5.74e-02, epoch duration = 0:00:01.454395
# 	D_KL = 0.015
# [BQRBM] epoch 67: β = 0.486, learning rate = 3.08e-02, β learning rate = 5.55e-02, epoch duration = 0:00:01.440417
# 	D_KL = 0.019
# [BQRBM] epoch 68: β = 0.487, learning rate = 2.87e-02, β learning rate = 5.36e-02, epoch duration = 0:00:01.452540
# 	D_KL = 0.017
# [BQRBM] epoch 69: β = 0.487, learning rate = 2.68e-02, β learning rate = 5.18e-02, epoch duration = 0:00:01.433806
# 	D_KL = 0.021
# [BQRBM] epoch 70: β = 0.486, learning rate = 2.50e-02, β learning rate = 5.00e-02, epoch duration = 0:00:01.456226
# 	D_KL = 0.016
# [BQRBM] epoch 71: β = 0.486, learning rate = 2.33e-02, β learning rate = 4.83e-02, epoch duration = 0:00:01.436268
# 	D_KL = 0.016
# [BQRBM] epoch 72: β = 0.487, learning rate = 2.18e-02, β learning rate = 4.67e-02, epoch duration = 0:00:01.452678
# 	D_KL = 0.019
# [BQRBM] epoch 73: β = 0.487, learning rate = 2.03e-02, β learning rate = 4.51e-02, epoch duration = 0:00:01.436685
# 	D_KL = 0.019
# [BQRBM] epoch 74: β = 0.487, learning rate = 1.89e-02, β learning rate = 4.35e-02, epoch duration = 0:00:01.450091
# 	D_KL = 0.020
# [BQRBM] epoch 75: β = 0.488, learning rate = 1.77e-02, β learning rate = 4.20e-02, epoch duration = 0:00:01.436529
# 	D_KL = 0.019
# [BQRBM] epoch 76: β = 0.487, learning rate = 1.65e-02, β learning rate = 4.06e-02, epoch duration = 0:00:01.450200
# 	D_KL = 0.016
# [BQRBM] epoch 77: β = 0.488, learning rate = 1.54e-02, β learning rate = 3.92e-02, epoch duration = 0:00:01.436843
# 	D_KL = 0.016
# [BQRBM] epoch 78: β = 0.488, learning rate = 1.44e-02, β learning rate = 3.79e-02, epoch duration = 0:00:01.452144
# 	D_KL = 0.018
# [BQRBM] epoch 79: β = 0.487, learning rate = 1.34e-02, β learning rate = 3.66e-02, epoch duration = 0:00:01.434377
# 	D_KL = 0.021
# [BQRBM] epoch 80: β = 0.488, learning rate = 1.25e-02, β learning rate = 3.54e-02, epoch duration = 0:00:01.458891
# 	D_KL = 0.018
# [BQRBM] epoch 81: β = 0.488, learning rate = 1.17e-02, β learning rate = 3.42e-02, epoch duration = 0:00:01.482690
# 	D_KL = 0.016
# [BQRBM] epoch 82: β = 0.487, learning rate = 1.09e-02, β learning rate = 3.30e-02, epoch duration = 0:00:01.463365
# 	D_KL = 0.016
# [BQRBM] epoch 83: β = 0.487, learning rate = 1.02e-02, β learning rate = 3.19e-02, epoch duration = 0:00:01.444799
# 	D_KL = 0.020
# [BQRBM] epoch 84: β = 0.486, learning rate = 9.47e-03, β learning rate = 3.08e-02, epoch duration = 0:00:01.439306
# 	D_KL = 0.018
# [BQRBM] epoch 85: β = 0.487, learning rate = 8.84e-03, β learning rate = 2.97e-02, epoch duration = 0:00:01.441436
# 	D_KL = 0.019
# [BQRBM] epoch 86: β = 0.486, learning rate = 8.25e-03, β learning rate = 2.87e-02, epoch duration = 0:00:01.446225
# 	D_KL = 0.016
# [BQRBM] epoch 87: β = 0.486, learning rate = 7.69e-03, β learning rate = 2.77e-02, epoch duration = 0:00:01.443335
# 	D_KL = 0.019
# [BQRBM] epoch 88: β = 0.487, learning rate = 7.18e-03, β learning rate = 2.68e-02, epoch duration = 0:00:01.444953
# 	D_KL = 0.015
# [BQRBM] epoch 89: β = 0.487, learning rate = 6.70e-03, β learning rate = 2.59e-02, epoch duration = 0:00:01.444483
# 	D_KL = 0.014
# [BQRBM] epoch 90: β = 0.486, learning rate = 6.25e-03, β learning rate = 2.50e-02, epoch duration = 0:00:01.448362
# 	D_KL = 0.016
# [BQRBM] epoch 91: β = 0.486, learning rate = 5.83e-03, β learning rate = 2.41e-02, epoch duration = 0:00:01.443503
# 	D_KL = 0.018
# [BQRBM] epoch 92: β = 0.486, learning rate = 5.44e-03, β learning rate = 2.33e-02, epoch duration = 0:00:01.446708
# 	D_KL = 0.018
# [BQRBM] epoch 93: β = 0.486, learning rate = 5.08e-03, β learning rate = 2.25e-02, epoch duration = 0:00:01.449274
# 	D_KL = 0.019
# [BQRBM] epoch 94: β = 0.486, learning rate = 4.74e-03, β learning rate = 2.18e-02, epoch duration = 0:00:01.441545
# 	D_KL = 0.018
# [BQRBM] epoch 95: β = 0.486, learning rate = 4.42e-03, β learning rate = 2.10e-02, epoch duration = 0:00:01.446874
# 	D_KL = 0.020
# [BQRBM] epoch 96: β = 0.485, learning rate = 4.12e-03, β learning rate = 2.03e-02, epoch duration = 0:00:01.448279
# 	D_KL = 0.016
# [BQRBM] epoch 97: β = 0.485, learning rate = 3.85e-03, β learning rate = 1.96e-02, epoch duration = 0:00:01.444370
# 	D_KL = 0.017
# [BQRBM] epoch 98: β = 0.486, learning rate = 3.59e-03, β learning rate = 1.89e-02, epoch duration = 0:00:01.444605
# 	D_KL = 0.019
# [BQRBM] epoch 99: β = 0.486, learning rate = 3.35e-03, β learning rate = 1.83e-02, epoch duration = 0:00:01.442951
# 	D_KL = 0.016
# [BQRBM] epoch 100: β = 0.486, learning rate = 3.13e-03, β learning rate = 1.77e-02, epoch duration = 0:00:01.445768
# 	D_KL = 0.019
# [BQRBM] epoch 1: β = 0.498, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.745250
# 	D_KL = 0.326
# [BQRBM] epoch 2: β = 0.496, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.735428
# 	D_KL = 0.301
# [BQRBM] epoch 3: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.739277
# 	D_KL = 0.288
# [BQRBM] epoch 4: β = 0.483, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.743361
# 	D_KL = 0.267
# [BQRBM] epoch 5: β = 0.475, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.732263
# 	D_KL = 0.240
# [BQRBM] epoch 6: β = 0.467, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.746697
# 	D_KL = 0.225
# [BQRBM] epoch 7: β = 0.458, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.735445
# 	D_KL = 0.199
# [BQRBM] epoch 8: β = 0.448, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.737669
# 	D_KL = 0.192
# [BQRBM] epoch 9: β = 0.441, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.744990
# 	D_KL = 0.174
# [BQRBM] epoch 10: β = 0.433, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.732708
# 	D_KL = 0.167
# [BQRBM] epoch 11: β = 0.426, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.730732
# 	D_KL = 0.140
# [BQRBM] epoch 12: β = 0.419, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.750190
# 	D_KL = 0.134
# [BQRBM] epoch 13: β = 0.415, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.731000
# 	D_KL = 0.116
# [BQRBM] epoch 14: β = 0.411, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.741201
# 	D_KL = 0.107
# [BQRBM] epoch 15: β = 0.409, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.738711
# 	D_KL = 0.092
# [BQRBM] epoch 16: β = 0.407, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.732641
# 	D_KL = 0.094
# [BQRBM] epoch 17: β = 0.405, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.745115
# 	D_KL = 0.082
# [BQRBM] epoch 18: β = 0.405, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.733407
# 	D_KL = 0.079
# [BQRBM] epoch 19: β = 0.407, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.731180
# 	D_KL = 0.075
# [BQRBM] epoch 20: β = 0.407, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.748133
# 	D_KL = 0.071
# [BQRBM] epoch 21: β = 0.408, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.732685
# 	D_KL = 0.071
# [BQRBM] epoch 22: β = 0.412, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.748322
# 	D_KL = 0.063
# [BQRBM] epoch 23: β = 0.414, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.736424
# 	D_KL = 0.067
# [BQRBM] epoch 24: β = 0.416, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.730119
# 	D_KL = 0.065
# [BQRBM] epoch 25: β = 0.419, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.747846
# 	D_KL = 0.061
# [BQRBM] epoch 26: β = 0.419, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.733672
# 	D_KL = 0.065
# [BQRBM] epoch 27: β = 0.420, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.732242
# 	D_KL = 0.067
# [BQRBM] epoch 28: β = 0.421, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.746533
# 	D_KL = 0.059
# [BQRBM] epoch 29: β = 0.423, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.730848
# 	D_KL = 0.056
# [BQRBM] epoch 30: β = 0.426, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.738922
# 	D_KL = 0.057
# [BQRBM] epoch 31: β = 0.428, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.740625
# 	D_KL = 0.056
# [BQRBM] epoch 32: β = 0.430, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.731018
# 	D_KL = 0.056
# [BQRBM] epoch 33: β = 0.432, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.744208
# 	D_KL = 0.055
# [BQRBM] epoch 34: β = 0.433, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.735656
# 	D_KL = 0.056
# [BQRBM] epoch 35: β = 0.435, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.731855
# 	D_KL = 0.055
# [BQRBM] epoch 36: β = 0.436, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.749237
# 	D_KL = 0.055
# [BQRBM] epoch 37: β = 0.436, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.732203
# 	D_KL = 0.060
# [BQRBM] epoch 38: β = 0.438, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.739452
# 	D_KL = 0.049
# [BQRBM] epoch 39: β = 0.440, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.738564
# 	D_KL = 0.050
# [BQRBM] epoch 40: β = 0.441, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.730463
# 	D_KL = 0.050
# [BQRBM] epoch 41: β = 0.444, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.739755
# 	D_KL = 0.051
# [BQRBM] epoch 42: β = 0.447, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.741706
# 	D_KL = 0.046
# [BQRBM] epoch 43: β = 0.448, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.731344
# 	D_KL = 0.052
# [BQRBM] epoch 44: β = 0.449, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.737617
# 	D_KL = 0.047
# [BQRBM] epoch 45: β = 0.449, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.742709
# 	D_KL = 0.050
# [BQRBM] epoch 46: β = 0.449, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.736753
# 	D_KL = 0.058
# [BQRBM] epoch 47: β = 0.452, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.753655
# 	D_KL = 0.049
# [BQRBM] epoch 48: β = 0.453, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.771443
# 	D_KL = 0.042
# [BQRBM] epoch 49: β = 0.453, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.793742
# 	D_KL = 0.049
# [BQRBM] epoch 50: β = 0.454, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.757226
# 	D_KL = 0.049
# [BQRBM] epoch 51: β = 0.456, learning rate = 9.33e-02, β learning rate = 9.66e-02, epoch duration = 0:00:00.729124
# 	D_KL = 0.047
# [BQRBM] epoch 52: β = 0.455, learning rate = 8.71e-02, β learning rate = 9.33e-02, epoch duration = 0:00:00.722672
# 	D_KL = 0.045
# [BQRBM] epoch 53: β = 0.454, learning rate = 8.12e-02, β learning rate = 9.01e-02, epoch duration = 0:00:00.734674
# 	D_KL = 0.051
# [BQRBM] epoch 54: β = 0.453, learning rate = 7.58e-02, β learning rate = 8.71e-02, epoch duration = 0:00:00.750528
# 	D_KL = 0.050
# [BQRBM] epoch 55: β = 0.454, learning rate = 7.07e-02, β learning rate = 8.41e-02, epoch duration = 0:00:00.746187
# 	D_KL = 0.048
# [BQRBM] epoch 56: β = 0.455, learning rate = 6.60e-02, β learning rate = 8.12e-02, epoch duration = 0:00:00.803668
# 	D_KL = 0.044
# [BQRBM] epoch 57: β = 0.456, learning rate = 6.16e-02, β learning rate = 7.85e-02, epoch duration = 0:00:00.768979
# 	D_KL = 0.053
# [BQRBM] epoch 58: β = 0.457, learning rate = 5.74e-02, β learning rate = 7.58e-02, epoch duration = 0:00:00.727616
# 	D_KL = 0.046
# [BQRBM] epoch 59: β = 0.458, learning rate = 5.36e-02, β learning rate = 7.32e-02, epoch duration = 0:00:00.722293
# 	D_KL = 0.042
# [BQRBM] epoch 60: β = 0.459, learning rate = 5.00e-02, β learning rate = 7.07e-02, epoch duration = 0:00:00.720325
# 	D_KL = 0.046
# [BQRBM] epoch 61: β = 0.459, learning rate = 4.67e-02, β learning rate = 6.83e-02, epoch duration = 0:00:00.732101
# 	D_KL = 0.044
# [BQRBM] epoch 62: β = 0.459, learning rate = 4.35e-02, β learning rate = 6.60e-02, epoch duration = 0:00:00.726220
# 	D_KL = 0.042
# [BQRBM] epoch 63: β = 0.460, learning rate = 4.06e-02, β learning rate = 6.37e-02, epoch duration = 0:00:00.730273
# 	D_KL = 0.047
# [BQRBM] epoch 64: β = 0.460, learning rate = 3.79e-02, β learning rate = 6.16e-02, epoch duration = 0:00:01.067353
# 	D_KL = 0.049
# [BQRBM] epoch 65: β = 0.459, learning rate = 3.54e-02, β learning rate = 5.95e-02, epoch duration = 0:00:01.102597
# 	D_KL = 0.055
# [BQRBM] epoch 66: β = 0.459, learning rate = 3.30e-02, β learning rate = 5.74e-02, epoch duration = 0:00:01.110469
# 	D_KL = 0.045
# [BQRBM] epoch 67: β = 0.462, learning rate = 3.08e-02, β learning rate = 5.55e-02, epoch duration = 0:00:01.095726
# 	D_KL = 0.044
# [BQRBM] epoch 68: β = 0.462, learning rate = 2.87e-02, β learning rate = 5.36e-02, epoch duration = 0:00:01.085047
# 	D_KL = 0.048
# [BQRBM] epoch 69: β = 0.463, learning rate = 2.68e-02, β learning rate = 5.18e-02, epoch duration = 0:00:01.106670
# 	D_KL = 0.047
# [BQRBM] epoch 70: β = 0.463, learning rate = 2.50e-02, β learning rate = 5.00e-02, epoch duration = 0:00:01.077601
# 	D_KL = 0.043
# [BQRBM] epoch 71: β = 0.463, learning rate = 2.33e-02, β learning rate = 4.83e-02, epoch duration = 0:00:01.116186
# 	D_KL = 0.047
# [BQRBM] epoch 72: β = 0.463, learning rate = 2.18e-02, β learning rate = 4.67e-02, epoch duration = 0:00:01.102566
# 	D_KL = 0.046
# [BQRBM] epoch 73: β = 0.463, learning rate = 2.03e-02, β learning rate = 4.51e-02, epoch duration = 0:00:01.207010
# 	D_KL = 0.048
# [BQRBM] epoch 74: β = 0.464, learning rate = 1.89e-02, β learning rate = 4.35e-02, epoch duration = 0:00:01.128602
# 	D_KL = 0.046
# [BQRBM] epoch 75: β = 0.465, learning rate = 1.77e-02, β learning rate = 4.20e-02, epoch duration = 0:00:01.149277
# 	D_KL = 0.050
# [BQRBM] epoch 76: β = 0.465, learning rate = 1.65e-02, β learning rate = 4.06e-02, epoch duration = 0:00:01.116997
# 	D_KL = 0.044
# [BQRBM] epoch 77: β = 0.465, learning rate = 1.54e-02, β learning rate = 3.92e-02, epoch duration = 0:00:01.210089
# 	D_KL = 0.044
# [BQRBM] epoch 78: β = 0.465, learning rate = 1.44e-02, β learning rate = 3.79e-02, epoch duration = 0:00:01.141345
# 	D_KL = 0.044
# [BQRBM] epoch 79: β = 0.465, learning rate = 1.34e-02, β learning rate = 3.66e-02, epoch duration = 0:00:01.198907
# 	D_KL = 0.048
# [BQRBM] epoch 80: β = 0.465, learning rate = 1.25e-02, β learning rate = 3.54e-02, epoch duration = 0:00:01.175429
# 	D_KL = 0.044
# [BQRBM] epoch 81: β = 0.465, learning rate = 1.17e-02, β learning rate = 3.42e-02, epoch duration = 0:00:01.317822
# 	D_KL = 0.043
# [BQRBM] epoch 82: β = 0.465, learning rate = 1.09e-02, β learning rate = 3.30e-02, epoch duration = 0:00:01.330795
# 	D_KL = 0.044
# [BQRBM] epoch 83: β = 0.464, learning rate = 1.02e-02, β learning rate = 3.19e-02, epoch duration = 0:00:01.326686
# 	D_KL = 0.048
# [BQRBM] epoch 84: β = 0.464, learning rate = 9.47e-03, β learning rate = 3.08e-02, epoch duration = 0:00:01.338573
# 	D_KL = 0.047
# [BQRBM] epoch 85: β = 0.465, learning rate = 8.84e-03, β learning rate = 2.97e-02, epoch duration = 0:00:01.315740
# 	D_KL = 0.047
# [BQRBM] epoch 86: β = 0.465, learning rate = 8.25e-03, β learning rate = 2.87e-02, epoch duration = 0:00:01.350439
# 	D_KL = 0.045
# [BQRBM] epoch 87: β = 0.465, learning rate = 7.69e-03, β learning rate = 2.77e-02, epoch duration = 0:00:01.314596
# 	D_KL = 0.049
# [BQRBM] epoch 88: β = 0.466, learning rate = 7.18e-03, β learning rate = 2.68e-02, epoch duration = 0:00:01.410234
# 	D_KL = 0.042
# [BQRBM] epoch 89: β = 0.465, learning rate = 6.70e-03, β learning rate = 2.59e-02, epoch duration = 0:00:01.338059
# 	D_KL = 0.042
# [BQRBM] epoch 90: β = 0.465, learning rate = 6.25e-03, β learning rate = 2.50e-02, epoch duration = 0:00:01.329284
# 	D_KL = 0.047
# [BQRBM] epoch 91: β = 0.465, learning rate = 5.83e-03, β learning rate = 2.41e-02, epoch duration = 0:00:01.336638
# 	D_KL = 0.047
# [BQRBM] epoch 92: β = 0.465, learning rate = 5.44e-03, β learning rate = 2.33e-02, epoch duration = 0:00:01.330235
# 	D_KL = 0.051
# [BQRBM] epoch 93: β = 0.465, learning rate = 5.08e-03, β learning rate = 2.25e-02, epoch duration = 0:00:01.333849
# 	D_KL = 0.048
# [BQRBM] epoch 94: β = 0.465, learning rate = 4.74e-03, β learning rate = 2.18e-02, epoch duration = 0:00:01.313323
# 	D_KL = 0.044
# [BQRBM] epoch 95: β = 0.465, learning rate = 4.42e-03, β learning rate = 2.10e-02, epoch duration = 0:00:01.336936
# 	D_KL = 0.046
# [BQRBM] epoch 96: β = 0.465, learning rate = 4.12e-03, β learning rate = 2.03e-02, epoch duration = 0:00:01.317165
# 	D_KL = 0.048
# [BQRBM] epoch 97: β = 0.465, learning rate = 3.85e-03, β learning rate = 1.96e-02, epoch duration = 0:00:01.311611
# 	D_KL = 0.045
# [BQRBM] epoch 98: β = 0.466, learning rate = 3.59e-03, β learning rate = 1.89e-02, epoch duration = 0:00:01.332922
# 	D_KL = 0.042
# [BQRBM] epoch 99: β = 0.465, learning rate = 3.35e-03, β learning rate = 1.83e-02, epoch duration = 0:00:01.341773
# 	D_KL = 0.039
# [BQRBM] epoch 100: β = 0.465, learning rate = 3.13e-03, β learning rate = 1.77e-02, epoch duration = 0:00:01.328287
# 	D_KL = 0.044
# [BQRBM] epoch 1: β = 0.502, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.695654
# 	D_KL = 0.344
# [BQRBM] epoch 2: β = 0.502, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.711145
# 	D_KL = 0.334
# [BQRBM] epoch 3: β = 0.501, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.692029
# 	D_KL = 0.333
# [BQRBM] epoch 4: β = 0.500, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.690478
# 	D_KL = 0.330
# [BQRBM] epoch 5: β = 0.498, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.694049
# 	D_KL = 0.309
# [BQRBM] epoch 6: β = 0.495, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.703095
# 	D_KL = 0.303
# [BQRBM] epoch 7: β = 0.491, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.709553
# 	D_KL = 0.289
# [BQRBM] epoch 8: β = 0.488, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.713719
# 	D_KL = 0.297
# [BQRBM] epoch 9: β = 0.484, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.727503
# 	D_KL = 0.288
# [BQRBM] epoch 10: β = 0.480, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.682899
# 	D_KL = 0.299
# [BQRBM] epoch 11: β = 0.477, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.698576
# 	D_KL = 0.273
# [BQRBM] epoch 12: β = 0.472, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.709204
# 	D_KL = 0.280
# [BQRBM] epoch 13: β = 0.468, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.688879
# 	D_KL = 0.256
# [BQRBM] epoch 14: β = 0.464, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.688781
# 	D_KL = 0.263
# [BQRBM] epoch 15: β = 0.461, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.692993
# 	D_KL = 0.248
# [BQRBM] epoch 16: β = 0.455, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.692950
# 	D_KL = 0.253
# [BQRBM] epoch 17: β = 0.450, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.692462
# 	D_KL = 0.241
# [BQRBM] epoch 18: β = 0.446, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.696200
# 	D_KL = 0.241
# [BQRBM] epoch 19: β = 0.442, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.694689
# 	D_KL = 0.227
# [BQRBM] epoch 20: β = 0.439, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.705226
# 	D_KL = 0.228
# [BQRBM] epoch 21: β = 0.435, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.692814
# 	D_KL = 0.225
# [BQRBM] epoch 22: β = 0.432, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.693145
# 	D_KL = 0.212
# [BQRBM] epoch 23: β = 0.428, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.707237
# 	D_KL = 0.213
# [BQRBM] epoch 24: β = 0.425, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.725276
# 	D_KL = 0.209
# [BQRBM] epoch 25: β = 0.423, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.728296
# 	D_KL = 0.194
# [BQRBM] epoch 26: β = 0.419, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.752578
# 	D_KL = 0.206
# [BQRBM] epoch 27: β = 0.415, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.659557
# 	D_KL = 0.201
# [BQRBM] epoch 28: β = 0.412, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.766603
# 	D_KL = 0.194
# [BQRBM] epoch 29: β = 0.410, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.736033
# 	D_KL = 0.178
# [BQRBM] epoch 30: β = 0.408, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.700199
# 	D_KL = 0.172
# [BQRBM] epoch 31: β = 0.405, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.681027
# 	D_KL = 0.175
# [BQRBM] epoch 32: β = 0.404, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.716558
# 	D_KL = 0.168
# [BQRBM] epoch 33: β = 0.403, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.660213
# 	D_KL = 0.161
# [BQRBM] epoch 34: β = 0.402, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.711887
# 	D_KL = 0.158
# [BQRBM] epoch 35: β = 0.401, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.594569
# 	D_KL = 0.154
# [BQRBM] epoch 36: β = 0.397, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.598909
# 	D_KL = 0.156
# [BQRBM] epoch 37: β = 0.394, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.567521
# 	D_KL = 0.150
# [BQRBM] epoch 38: β = 0.393, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.590445
# 	D_KL = 0.143
# [BQRBM] epoch 39: β = 0.392, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.609037
# 	D_KL = 0.131
# [BQRBM] epoch 40: β = 0.391, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.606463
# 	D_KL = 0.135
# [BQRBM] epoch 41: β = 0.391, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.649233
# 	D_KL = 0.128
# [BQRBM] epoch 42: β = 0.392, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.654424
# 	D_KL = 0.115
# [BQRBM] epoch 43: β = 0.391, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.662091
# 	D_KL = 0.130
# [BQRBM] epoch 44: β = 0.391, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.693251
# 	D_KL = 0.122
# [BQRBM] epoch 45: β = 0.391, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.648770
# 	D_KL = 0.118
# [BQRBM] epoch 46: β = 0.391, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.648956
# 	D_KL = 0.124
# [BQRBM] epoch 47: β = 0.391, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.638472
# 	D_KL = 0.113
# [BQRBM] epoch 48: β = 0.390, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.603848
# 	D_KL = 0.111
# [BQRBM] epoch 49: β = 0.389, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.591381
# 	D_KL = 0.111
# [BQRBM] epoch 50: β = 0.390, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.608328
# 	D_KL = 0.109
# [BQRBM] epoch 51: β = 0.390, learning rate = 9.33e-02, β learning rate = 9.66e-02, epoch duration = 0:00:00.603613
# 	D_KL = 0.104
# [BQRBM] epoch 52: β = 0.391, learning rate = 8.71e-02, β learning rate = 9.33e-02, epoch duration = 0:00:00.593153
# 	D_KL = 0.103
# [BQRBM] epoch 53: β = 0.391, learning rate = 8.12e-02, β learning rate = 9.01e-02, epoch duration = 0:00:00.624415
# 	D_KL = 0.104
# [BQRBM] epoch 54: β = 0.391, learning rate = 7.58e-02, β learning rate = 8.71e-02, epoch duration = 0:00:00.650247
# 	D_KL = 0.107
# [BQRBM] epoch 55: β = 0.391, learning rate = 7.07e-02, β learning rate = 8.41e-02, epoch duration = 0:00:00.650510
# 	D_KL = 0.098
# [BQRBM] epoch 56: β = 0.391, learning rate = 6.60e-02, β learning rate = 8.12e-02, epoch duration = 0:00:00.655915
# 	D_KL = 0.101
# [BQRBM] epoch 57: β = 0.391, learning rate = 6.16e-02, β learning rate = 7.85e-02, epoch duration = 0:00:00.639788
# 	D_KL = 0.099
# [BQRBM] epoch 58: β = 0.391, learning rate = 5.74e-02, β learning rate = 7.58e-02, epoch duration = 0:00:00.666955
# 	D_KL = 0.095
# [BQRBM] epoch 59: β = 0.390, learning rate = 5.36e-02, β learning rate = 7.32e-02, epoch duration = 0:00:00.645647
# 	D_KL = 0.089
# [BQRBM] epoch 60: β = 0.391, learning rate = 5.00e-02, β learning rate = 7.07e-02, epoch duration = 0:00:00.654640
# 	D_KL = 0.089
# [BQRBM] epoch 61: β = 0.392, learning rate = 4.67e-02, β learning rate = 6.83e-02, epoch duration = 0:00:00.651524
# 	D_KL = 0.088
# [BQRBM] epoch 62: β = 0.391, learning rate = 4.35e-02, β learning rate = 6.60e-02, epoch duration = 0:00:00.656844
# 	D_KL = 0.091
# [BQRBM] epoch 63: β = 0.392, learning rate = 4.06e-02, β learning rate = 6.37e-02, epoch duration = 0:00:00.649363
# 	D_KL = 0.091
# [BQRBM] epoch 64: β = 0.391, learning rate = 3.79e-02, β learning rate = 6.16e-02, epoch duration = 0:00:00.644800
# 	D_KL = 0.100
# [BQRBM] epoch 65: β = 0.391, learning rate = 3.54e-02, β learning rate = 5.95e-02, epoch duration = 0:00:00.652955
# 	D_KL = 0.103
# [BQRBM] epoch 66: β = 0.392, learning rate = 3.30e-02, β learning rate = 5.74e-02, epoch duration = 0:00:00.653321
# 	D_KL = 0.090
# [BQRBM] epoch 67: β = 0.393, learning rate = 3.08e-02, β learning rate = 5.55e-02, epoch duration = 0:00:00.650752
# 	D_KL = 0.092
# [BQRBM] epoch 68: β = 0.393, learning rate = 2.87e-02, β learning rate = 5.36e-02, epoch duration = 0:00:00.640092
# 	D_KL = 0.092
# [BQRBM] epoch 69: β = 0.393, learning rate = 2.68e-02, β learning rate = 5.18e-02, epoch duration = 0:00:00.665882
# 	D_KL = 0.095
# [BQRBM] epoch 70: β = 0.392, learning rate = 2.50e-02, β learning rate = 5.00e-02, epoch duration = 0:00:00.642448
# 	D_KL = 0.099
# [BQRBM] epoch 71: β = 0.392, learning rate = 2.33e-02, β learning rate = 4.83e-02, epoch duration = 0:00:00.648827
# 	D_KL = 0.094
# [BQRBM] epoch 72: β = 0.393, learning rate = 2.18e-02, β learning rate = 4.67e-02, epoch duration = 0:00:00.643015
# 	D_KL = 0.091
# ...
# 	D_KL = 0.201
# [BQRBM] epoch 78: β = 0.410, learning rate = 1.44e-02, β learning rate = 3.79e-02, epoch duration = 0:00:00.423503
# 	D_KL = 0.196
# [BQRBM] epoch 79: β = 0.410, learning rate = 1.34e-02, β learning rate = 3.66e-02, epoch duration = 0:00:00.452604
# 	D_KL = 0.213
# [BQRBM] epoch 80: β = 0.410, learning rate = 1.25e-02, β learning rate = 3.54e-02, epoch duration = 0:00:00.381204
# 	D_KL = 0.200
# [BQRBM] epoch 81: β = 0.409, learning rate = 1.17e-02, β learning rate = 3.42e-02, epoch duration = 0:00:00.393752
# 	D_KL = 0.197
# [BQRBM] epoch 82: β = 0.409, learning rate = 1.09e-02, β learning rate = 3.30e-02, epoch duration = 0:00:00.359172
# 	D_KL = 0.209
# [BQRBM] epoch 83: β = 0.409, learning rate = 1.02e-02, β learning rate = 3.19e-02, epoch duration = 0:00:00.390622
# 	D_KL = 0.200
# [BQRBM] epoch 84: β = 0.409, learning rate = 9.47e-03, β learning rate = 3.08e-02, epoch duration = 0:00:00.504305
# 	D_KL = 0.208
# [BQRBM] epoch 85: β = 0.409, learning rate = 8.84e-03, β learning rate = 2.97e-02, epoch duration = 0:00:00.424723
# 	D_KL = 0.196
# [BQRBM] epoch 86: β = 0.408, learning rate = 8.25e-03, β learning rate = 2.87e-02, epoch duration = 0:00:00.434741
# 	D_KL = 0.201
# [BQRBM] epoch 87: β = 0.408, learning rate = 7.69e-03, β learning rate = 2.77e-02, epoch duration = 0:00:00.432606
# 	D_KL = 0.200
# [BQRBM] epoch 88: β = 0.409, learning rate = 7.18e-03, β learning rate = 2.68e-02, epoch duration = 0:00:00.458191
# 	D_KL = 0.202
# [BQRBM] epoch 89: β = 0.408, learning rate = 6.70e-03, β learning rate = 2.59e-02, epoch duration = 0:00:00.504139
# 	D_KL = 0.210
# [BQRBM] epoch 90: β = 0.408, learning rate = 6.25e-03, β learning rate = 2.50e-02, epoch duration = 0:00:00.456805
# 	D_KL = 0.216
# [BQRBM] epoch 91: β = 0.408, learning rate = 5.83e-03, β learning rate = 2.41e-02, epoch duration = 0:00:00.447277
# 	D_KL = 0.208
# [BQRBM] epoch 92: β = 0.408, learning rate = 5.44e-03, β learning rate = 2.33e-02, epoch duration = 0:00:00.430973
# 	D_KL = 0.203
# [BQRBM] epoch 93: β = 0.407, learning rate = 5.08e-03, β learning rate = 2.25e-02, epoch duration = 0:00:00.486928
# 	D_KL = 0.200
# [BQRBM] epoch 94: β = 0.408, learning rate = 4.74e-03, β learning rate = 2.18e-02, epoch duration = 0:00:00.424756
# 	D_KL = 0.196
# [BQRBM] epoch 95: β = 0.408, learning rate = 4.42e-03, β learning rate = 2.10e-02, epoch duration = 0:00:00.374675
# 	D_KL = 0.201
# [BQRBM] epoch 96: β = 0.408, learning rate = 4.12e-03, β learning rate = 2.03e-02, epoch duration = 0:00:00.386624
# 	D_KL = 0.203
# [BQRBM] epoch 97: β = 0.408, learning rate = 3.85e-03, β learning rate = 1.96e-02, epoch duration = 0:00:00.427136
# 	D_KL = 0.203
# [BQRBM] epoch 98: β = 0.408, learning rate = 3.59e-03, β learning rate = 1.89e-02, epoch duration = 0:00:00.471007
# 	D_KL = 0.200
# [BQRBM] epoch 99: β = 0.408, learning rate = 3.35e-03, β learning rate = 1.83e-02, epoch duration = 0:00:00.453193
# 	D_KL = 0.199
# [BQRBM] epoch 100: β = 0.408, learning rate = 3.13e-03, β learning rate = 1.77e-02, epoch duration = 0:00:00.435430
# 	D_KL = 0.200
# [BQRBM] epoch 1: β = 0.503, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.357355
# 	D_KL = 0.347
# [BQRBM] epoch 2: β = 0.504, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.367281
# 	D_KL = 0.344
# [BQRBM] epoch 3: β = 0.504, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.326601
# 	D_KL = 0.347
# [BQRBM] epoch 4: β = 0.506, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.265958
# 	D_KL = 0.349
# [BQRBM] epoch 5: β = 0.508, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.305406
# 	D_KL = 0.334
# [BQRBM] epoch 6: β = 0.509, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.267688
# 	D_KL = 0.334
# [BQRBM] epoch 7: β = 0.511, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.276400
# 	D_KL = 0.326
# [BQRBM] epoch 8: β = 0.510, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.294894
# 	D_KL = 0.332
# [BQRBM] epoch 9: β = 0.509, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.297129
# 	D_KL = 0.331
# [BQRBM] epoch 10: β = 0.507, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.266089
# 	D_KL = 0.346
# [BQRBM] epoch 11: β = 0.507, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.277356
# 	D_KL = 0.328
# [BQRBM] epoch 12: β = 0.506, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.295071
# 	D_KL = 0.331
# [BQRBM] epoch 13: β = 0.505, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.381963
# 	D_KL = 0.309
# [BQRBM] epoch 14: β = 0.504, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.329458
# 	D_KL = 0.323
# [BQRBM] epoch 15: β = 0.503, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.362150
# 	D_KL = 0.315
# [BQRBM] epoch 16: β = 0.502, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.405297
# 	D_KL = 0.330
# [BQRBM] epoch 17: β = 0.501, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.378889
# 	D_KL = 0.317
# [BQRBM] epoch 18: β = 0.498, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.316591
# 	D_KL = 0.318
# [BQRBM] epoch 19: β = 0.496, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.329776
# 	D_KL = 0.309
# [BQRBM] epoch 20: β = 0.496, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.310586
# 	D_KL = 0.305
# [BQRBM] epoch 21: β = 0.494, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.396158
# 	D_KL = 0.313
# [BQRBM] epoch 22: β = 0.491, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.329438
# 	D_KL = 0.305
# [BQRBM] epoch 23: β = 0.490, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.298765
# 	D_KL = 0.310
# [BQRBM] epoch 24: β = 0.489, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.329088
# 	D_KL = 0.305
# [BQRBM] epoch 25: β = 0.487, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.333840
# 	D_KL = 0.298
# [BQRBM] epoch 26: β = 0.485, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.325236
# 	D_KL = 0.311
# [BQRBM] epoch 27: β = 0.483, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.307817
# 	D_KL = 0.306
# [BQRBM] epoch 28: β = 0.481, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.327010
# 	D_KL = 0.312
# [BQRBM] epoch 29: β = 0.479, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.328889
# 	D_KL = 0.300
# [BQRBM] epoch 30: β = 0.478, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.313973
# 	D_KL = 0.300
# [BQRBM] epoch 31: β = 0.478, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.324830
# 	D_KL = 0.306
# [BQRBM] epoch 32: β = 0.477, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.326563
# 	D_KL = 0.305
# [BQRBM] epoch 33: β = 0.476, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.326007
# 	D_KL = 0.294
# [BQRBM] epoch 34: β = 0.474, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.336568
# 	D_KL = 0.297
# [BQRBM] epoch 35: β = 0.475, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.306527
# 	D_KL = 0.285
# [BQRBM] epoch 36: β = 0.472, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.311587
# 	D_KL = 0.302
# [BQRBM] epoch 37: β = 0.470, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.325984
# 	D_KL = 0.303
# [BQRBM] epoch 38: β = 0.466, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.335694
# 	D_KL = 0.291
# [BQRBM] epoch 39: β = 0.465, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.322947
# 	D_KL = 0.275
# [BQRBM] epoch 40: β = 0.462, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.308606
# 	D_KL = 0.275
# [BQRBM] epoch 41: β = 0.460, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.332771
# 	D_KL = 0.275
# [BQRBM] epoch 42: β = 0.459, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.332929
# 	D_KL = 0.256
# [BQRBM] epoch 43: β = 0.458, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.321802
# 	D_KL = 0.281
# [BQRBM] epoch 44: β = 0.455, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.310474
# 	D_KL = 0.278
# [BQRBM] epoch 45: β = 0.454, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.350223
# 	D_KL = 0.270
# [BQRBM] epoch 46: β = 0.452, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.326305
# 	D_KL = 0.279
# [BQRBM] epoch 47: β = 0.450, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.322608
# 	D_KL = 0.267
# [BQRBM] epoch 48: β = 0.450, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.328152
# 	D_KL = 0.268
# [BQRBM] epoch 49: β = 0.449, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.293152
# 	D_KL = 0.268
# [BQRBM] epoch 50: β = 0.449, learning rate = 1.00e-01, β learning rate = 1.00e-01, epoch duration = 0:00:00.280303
# 	D_KL = 0.271
# [BQRBM] epoch 51: β = 0.447, learning rate = 9.33e-02, β learning rate = 9.66e-02, epoch duration = 0:00:00.329293
# 	D_KL = 0.266
# [BQRBM] epoch 52: β = 0.445, learning rate = 8.71e-02, β learning rate = 9.33e-02, epoch duration = 0:00:00.307042
# 	D_KL = 0.264
# [BQRBM] epoch 53: β = 0.445, learning rate = 8.12e-02, β learning rate = 9.01e-02, epoch duration = 0:00:00.331364
# 	D_KL = 0.264
# [BQRBM] epoch 54: β = 0.445, learning rate = 7.58e-02, β learning rate = 8.71e-02, epoch duration = 0:00:00.308070
# 	D_KL = 0.268
# [BQRBM] epoch 55: β = 0.443, learning rate = 7.07e-02, β learning rate = 8.41e-02, epoch duration = 0:00:00.320227
# 	D_KL = 0.259
# [BQRBM] epoch 56: β = 0.441, learning rate = 6.60e-02, β learning rate = 8.12e-02, epoch duration = 0:00:00.411849
# 	D_KL = 0.265
# [BQRBM] epoch 57: β = 0.440, learning rate = 6.16e-02, β learning rate = 7.85e-02, epoch duration = 0:00:00.333797
# 	D_KL = 0.254
# [BQRBM] epoch 58: β = 0.439, learning rate = 5.74e-02, β learning rate = 7.58e-02, epoch duration = 0:00:00.357345
# 	D_KL = 0.264
# [BQRBM] epoch 59: β = 0.438, learning rate = 5.36e-02, β learning rate = 7.32e-02, epoch duration = 0:00:00.305115
# 	D_KL = 0.253
# [BQRBM] epoch 60: β = 0.437, learning rate = 5.00e-02, β learning rate = 7.07e-02, epoch duration = 0:00:00.279675
# 	D_KL = 0.244
# [BQRBM] epoch 61: β = 0.437, learning rate = 4.67e-02, β learning rate = 6.83e-02, epoch duration = 0:00:00.301702
# 	D_KL = 0.250
# [BQRBM] epoch 62: β = 0.437, learning rate = 4.35e-02, β learning rate = 6.60e-02, epoch duration = 0:00:00.354300
# 	D_KL = 0.264
# [BQRBM] epoch 63: β = 0.436, learning rate = 4.06e-02, β learning rate = 6.37e-02, epoch duration = 0:00:00.376223
# 	D_KL = 0.255
# [BQRBM] epoch 64: β = 0.435, learning rate = 3.79e-02, β learning rate = 6.16e-02, epoch duration = 0:00:00.372605
# 	D_KL = 0.264
# [BQRBM] epoch 65: β = 0.434, learning rate = 3.54e-02, β learning rate = 5.95e-02, epoch duration = 0:00:00.300665
# 	D_KL = 0.261
# [BQRBM] epoch 66: β = 0.433, learning rate = 3.30e-02, β learning rate = 5.74e-02, epoch duration = 0:00:00.346754
# 	D_KL = 0.267
# [BQRBM] epoch 67: β = 0.433, learning rate = 3.08e-02, β learning rate = 5.55e-02, epoch duration = 0:00:00.412099
# 	D_KL = 0.247
# [BQRBM] epoch 68: β = 0.432, learning rate = 2.87e-02, β learning rate = 5.36e-02, epoch duration = 0:00:00.369564
# 	D_KL = 0.254
# [BQRBM] epoch 69: β = 0.432, learning rate = 2.68e-02, β learning rate = 5.18e-02, epoch duration = 0:00:00.396441
# 	D_KL = 0.251
# [BQRBM] epoch 70: β = 0.432, learning rate = 2.50e-02, β learning rate = 5.00e-02, epoch duration = 0:00:00.368481
# 	D_KL = 0.272
# [BQRBM] epoch 71: β = 0.432, learning rate = 2.33e-02, β learning rate = 4.83e-02, epoch duration = 0:00:00.364933
# 	D_KL = 0.256
# [BQRBM] epoch 72: β = 0.432, learning rate = 2.18e-02, β learning rate = 4.67e-02, epoch duration = 0:00:00.364208
# 	D_KL = 0.255
# [BQRBM] epoch 73: β = 0.432, learning rate = 2.03e-02, β learning rate = 4.51e-02, epoch duration = 0:00:00.360264
# 	D_KL = 0.253
# [BQRBM] epoch 74: β = 0.432, learning rate = 1.89e-02, β learning rate = 4.35e-02, epoch duration = 0:00:00.353279
# 	D_KL = 0.243
# [BQRBM] epoch 75: β = 0.431, learning rate = 1.77e-02, β learning rate = 4.20e-02, epoch duration = 0:00:00.365103
# 	D_KL = 0.254
# [BQRBM] epoch 76: β = 0.431, learning rate = 1.65e-02, β learning rate = 4.06e-02, epoch duration = 0:00:00.385575
# 	D_KL = 0.249
# [BQRBM] epoch 77: β = 0.431, learning rate = 1.54e-02, β learning rate = 3.92e-02, epoch duration = 0:00:00.364097
# 	D_KL = 0.246
# [BQRBM] epoch 78: β = 0.431, learning rate = 1.44e-02, β learning rate = 3.79e-02, epoch duration = 0:00:00.370828
# 	D_KL = 0.242
# [BQRBM] epoch 79: β = 0.431, learning rate = 1.34e-02, β learning rate = 3.66e-02, epoch duration = 0:00:00.364141
# 	D_KL = 0.255
# [BQRBM] epoch 80: β = 0.431, learning rate = 1.25e-02, β learning rate = 3.54e-02, epoch duration = 0:00:00.369409
# 	D_KL = 0.246
# [BQRBM] epoch 81: β = 0.430, learning rate = 1.17e-02, β learning rate = 3.42e-02, epoch duration = 0:00:00.348614
# 	D_KL = 0.242
# [BQRBM] epoch 82: β = 0.430, learning rate = 1.09e-02, β learning rate = 3.30e-02, epoch duration = 0:00:00.368017
# 	D_KL = 0.254
# [BQRBM] epoch 83: β = 0.431, learning rate = 1.02e-02, β learning rate = 3.19e-02, epoch duration = 0:00:00.313773
# 	D_KL = 0.243
# [BQRBM] epoch 84: β = 0.431, learning rate = 9.47e-03, β learning rate = 3.08e-02, epoch duration = 0:00:00.310276
# 	D_KL = 0.251
# [BQRBM] epoch 85: β = 0.430, learning rate = 8.84e-03, β learning rate = 2.97e-02, epoch duration = 0:00:00.357002
# 	D_KL = 0.241
# [BQRBM] epoch 86: β = 0.430, learning rate = 8.25e-03, β learning rate = 2.87e-02, epoch duration = 0:00:00.370237
# 	D_KL = 0.245
# [BQRBM] epoch 87: β = 0.431, learning rate = 7.69e-03, β learning rate = 2.77e-02, epoch duration = 0:00:00.379293
# 	D_KL = 0.247
# [BQRBM] epoch 88: β = 0.431, learning rate = 7.18e-03, β learning rate = 2.68e-02, epoch duration = 0:00:00.433213
# 	D_KL = 0.250
# [BQRBM] epoch 89: β = 0.431, learning rate = 6.70e-03, β learning rate = 2.59e-02, epoch duration = 0:00:00.329005
# 	D_KL = 0.261
# [BQRBM] epoch 90: β = 0.431, learning rate = 6.25e-03, β learning rate = 2.50e-02, epoch duration = 0:00:00.374601
# 	D_KL = 0.262
# [BQRBM] epoch 91: β = 0.430, learning rate = 5.83e-03, β learning rate = 2.41e-02, epoch duration = 0:00:00.359165
# 	D_KL = 0.254
# [BQRBM] epoch 92: β = 0.430, learning rate = 5.44e-03, β learning rate = 2.33e-02, epoch duration = 0:00:00.367744
# 	D_KL = 0.251
# [BQRBM] epoch 93: β = 0.430, learning rate = 5.08e-03, β learning rate = 2.25e-02, epoch duration = 0:00:00.341139
# 	D_KL = 0.245
# [BQRBM] epoch 94: β = 0.430, learning rate = 4.74e-03, β learning rate = 2.18e-02, epoch duration = 0:00:00.323620
# 	D_KL = 0.241
# [BQRBM] epoch 95: β = 0.431, learning rate = 4.42e-03, β learning rate = 2.10e-02, epoch duration = 0:00:00.334976
# 	D_KL = 0.246
# [BQRBM] epoch 96: β = 0.430, learning rate = 4.12e-03, β learning rate = 2.03e-02, epoch duration = 0:00:00.350026
# 	D_KL = 0.248
# [BQRBM] epoch 97: β = 0.430, learning rate = 3.85e-03, β learning rate = 1.96e-02, epoch duration = 0:00:00.329078
# 	D_KL = 0.251
# [BQRBM] epoch 98: β = 0.430, learning rate = 3.59e-03, β learning rate = 1.89e-02, epoch duration = 0:00:00.352438
# 	D_KL = 0.249
# [BQRBM] epoch 99: β = 0.430, learning rate = 3.35e-03, β learning rate = 1.83e-02, epoch duration = 0:00:00.327515
# 	D_KL = 0.244
# [BQRBM] epoch 100: β = 0.430, learning rate = 3.13e-03, β learning rate = 1.77e-02, epoch duration = 0:00:00.342679
# 	D_KL = 0.245
# time: 10min 23s (started: 2022-01-29 21:07:24 +01:00)

# %%
markers = ["o", "^", "v", "<", ">", "s", "p", "*", "P", "X"]
colors = [
    "tab:blue",
    "tab:orange",
    "tab:green",
    "tab:red",
    "tab:purple",
    "tab:brown",
    "tab:pink",
    "tab:gray",
    "tab:olive",
    "tab:cyan",
]

fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
for i, mbs in enumerate(mini_batch_sizes):
    dkls = [x["value"] for x in models[mbs].callback_outputs]
    epochs = np.arange(1, len(dkls) + 1)
    ax.plot(epochs, dkls, label=f"Batch Size = {mbs}", color=colors[i], marker=markers[i], markevery=3)
    
ax.set_xlabel("Epoch")
ax.set_ylabel(r"$D_{KL}(p_{data} \ || \ p_{model})$")
ax.set_ylim((0, 0.5))
ax.set_yticks(np.arange(0, 55, 5) / 100)
ax.grid()
ax.legend()
plt.savefig(plot_dir / "batch_size_comparison.png")
