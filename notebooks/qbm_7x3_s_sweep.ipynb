# %% [markdown]
# # Exact QBM $s^*$ Comparison

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext autotime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import neptune.new as neptune
from scipy.constants import k as k_B, h as h_P

k_B /= h_P * 1e9

from qbm.utils import (
    binarize_df,
    convert_bin_list_to_str,
    get_binarization_params,
    get_project_dir,
    get_rng,
    kl_divergence,
    load_artifact,
    lr_exp_decay,
    prepare_training_data,
    save_artifact,
    unbinarize_df,
)
from qbm.models import BQRBM

# configure directories
project_dir = get_project_dir()
artifact_dir = project_dir / "artifacts/qbm/7x3"
if not artifact_dir.exists():
    artifact_dir.mkdir(parents=True)
plot_dir = project_dir / "results/plots/qbm/7x3"
if not plot_dir.exists():
    plot_dir.mkdir(parents=True)
    
# load anneal schedule
df_anneal = pd.read_csv(
    project_dir
    / "data/anneal_schedules/csv/09-1265A-A_Advantage_system5_1_annealing_schedule.csv",
    index_col="s",
)
if 0.5 not in df_anneal.index:
    df_anneal.loc[0.5] = (df_anneal.loc[0.499] + df_anneal.loc[0.501]) / 2
# Out:
# time: 1.89 s (started: 2022-02-24 09:43:06 +01:00)

# %% [markdown]
# ## Train Data Creation

# %%
seed = 42
n_visible = 7
n_hidden = 3
n_qubits = n_visible + n_hidden

rng = get_rng(seed)
n_samples = 1500
α = 2 / 3
N_1 = rng.normal(-2, 1, int(round(n_samples * α, 0)))
N_2 = rng.normal(3, 1, int(round(n_samples * (1 - α), 0)))
x = np.concatenate((N_1, N_2))

df = pd.DataFrame.from_dict({"x": x})
binarization_params = get_binarization_params(df, n_bits=n_visible)
df_binarized = binarize_df(df, binarization_params)
X_train = prepare_training_data(df_binarized)["X_train"]
# Out:
# time: 8.06 ms (started: 2022-02-24 09:43:08 +01:00)

# %%
def callback(model, sample_state_vectors):
    X_train = model.X_train
    n_visible = model.X_train.shape[1]
    train_states = (
        model._eigen_to_binary(model.X_train) * 2.0 ** np.arange(n_visible - 1, -1, -1)
    ).sum(axis=1)
    sample_states = (
        model._eigen_to_binary(sample_state_vectors[:, :n_visible])
        * 2.0 ** np.arange(n_visible - 1, -1, -1)
    ).sum(axis=1)

    dkl = kl_divergence(train_states, sample_states, n_bins=32)

    return {"value": dkl, "print": f"D_KL = {dkl:.3f}"}
# Out:
# time: 71.2 ms (started: 2022-02-24 09:43:08 +01:00)

# %% [markdown]
# ## Model Analysis (Exact)

# %%
# model params
embedding = None

# training params
n_epochs = 100
n_samples = 10_000
learning_rate = 0.1
mini_batch_size = 10
decay_epoch = 50
decay_period = 10
epochs = np.arange(1, n_epochs + 1)
learning_rates = learning_rate * lr_exp_decay(epochs, decay_epoch, decay_period)
learning_rates_beta = learning_rates
learning_rates_beta[:10] *= 5
learning_rates_beta[10:20] *= 2

train = True
s_values = np.round(np.arange(45, 105, 5) / 100, 2)
B_values = np.array([df_anneal.loc[s, "B(s) (GHz)"] for s in s_values])
beta_B_const = 80 / k_B
betas = beta_B_const / B_values
for i, s in enumerate(s_values):
    exact_params = {"beta": betas[i]}
    print(f"s = {s:.2f}, β = {betas[i]}")
    model_path = artifact_dir / f"models/model_exact-s={s:.2f}.pkl"
    if train:
        anneal_params = {
            "s": s,
            "A": df_anneal.loc[s, "A(s) (GHz)"],
            "B": df_anneal.loc[s, "B(s) (GHz)"],
        }
        # model init
        model = BQRBM(
            X_train=X_train,
            n_hidden=n_hidden,
            embedding=embedding,
            anneal_params=anneal_params,
            beta_initial=betas[i],
            beta_range=(1e-3, 10),
            exact_params=exact_params,
            seed=i,
        )

        # model train and save
        model.train(
            n_epochs=n_epochs,
            n_samples=n_samples,
            learning_rate=learning_rates,
            learning_rate_beta=0.0,
            mini_batch_size=mini_batch_size,
            callback=callback,
        )
        model.save(model_path)
    else:
        model = BQRBM.load(model_path)
# Out:
# s = 0.45, β = 1.4998191177770177
# [BQRBM] epoch 1: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:23.407855
# D_KL = 0.077
# [BQRBM] epoch 2: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:23.451827
# D_KL = 0.064
# [BQRBM] epoch 3: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:23.192144
# D_KL = 0.057
# [BQRBM] epoch 4: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.973227
# D_KL = 0.090
# [BQRBM] epoch 5: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.702656
# D_KL = 0.073
# [BQRBM] epoch 6: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.685196
# D_KL = 0.041
# [BQRBM] epoch 7: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.544190
# D_KL = 0.032
# [BQRBM] epoch 8: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.948045
# D_KL = 0.125
# [BQRBM] epoch 9: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.622701
# D_KL = 0.047
# [BQRBM] epoch 10: β = 1.500, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.687016
# D_KL = 0.052
# [BQRBM] epoch 11: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.807646
# D_KL = 0.023
# [BQRBM] epoch 12: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.616200
# D_KL = 0.021
# [BQRBM] epoch 13: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.875870
# D_KL = 0.020
# [BQRBM] epoch 14: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.537463
# D_KL = 0.019
# [BQRBM] epoch 15: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.735560
# D_KL = 0.022
# [BQRBM] epoch 16: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.539373
# D_KL = 0.025
# [BQRBM] epoch 17: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.643355
# D_KL = 0.024
# [BQRBM] epoch 18: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.523489
# D_KL = 0.025
# [BQRBM] epoch 19: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.669722
# D_KL = 0.022
# [BQRBM] epoch 20: β = 1.500, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.471480
# D_KL = 0.028
# [BQRBM] epoch 21: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.737820
# D_KL = 0.019
# [BQRBM] epoch 22: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.496092
# D_KL = 0.016
# [BQRBM] epoch 23: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.545263
# D_KL = 0.020
# [BQRBM] epoch 24: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.467010
# D_KL = 0.018
# [BQRBM] epoch 25: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.527580
# D_KL = 0.019
# [BQRBM] epoch 26: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.397444
# D_KL = 0.020
# [BQRBM] epoch 27: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.711366
# D_KL = 0.012
# [BQRBM] epoch 28: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.384786
# D_KL = 0.015
# [BQRBM] epoch 29: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.508519
# D_KL = 0.020
# [BQRBM] epoch 30: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.491991
# D_KL = 0.015
# [BQRBM] epoch 31: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.516158
# D_KL = 0.014
# [BQRBM] epoch 32: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.528422
# D_KL = 0.020
# [BQRBM] epoch 33: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.583865
# D_KL = 0.014
# [BQRBM] epoch 34: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.434299
# D_KL = 0.020
# [BQRBM] epoch 35: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.686811
# D_KL = 0.028
# [BQRBM] epoch 36: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.396029
# D_KL = 0.017
# [BQRBM] epoch 37: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.521199
# D_KL = 0.014
# [BQRBM] epoch 38: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.596225
# D_KL = 0.016
# [BQRBM] epoch 39: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.491828
# D_KL = 0.019
# [BQRBM] epoch 40: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.404911
# D_KL = 0.016
# [BQRBM] epoch 41: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.778713
# D_KL = 0.018
# [BQRBM] epoch 42: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.457197
# D_KL = 0.019
# [BQRBM] epoch 43: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.692645
# D_KL = 0.018
# [BQRBM] epoch 44: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.541174
# D_KL = 0.015
# [BQRBM] epoch 45: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.478996
# D_KL = 0.016
# [BQRBM] epoch 46: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.492908
# D_KL = 0.017
# [BQRBM] epoch 47: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.425189
# D_KL = 0.018
# [BQRBM] epoch 48: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.409850
# D_KL = 0.019
# [BQRBM] epoch 49: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.711230
# D_KL = 0.014
# [BQRBM] epoch 50: β = 1.500, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:22.395804
# D_KL = 0.014
# [BQRBM] epoch 51: β = 1.500, learning rate = 9.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.666599
# D_KL = 0.016
# [BQRBM] epoch 52: β = 1.500, learning rate = 8.71e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.567801
# D_KL = 0.012
# [BQRBM] epoch 53: β = 1.500, learning rate = 8.12e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.504659
# D_KL = 0.016
# [BQRBM] epoch 54: β = 1.500, learning rate = 7.58e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.492724
# D_KL = 0.013
# [BQRBM] epoch 55: β = 1.500, learning rate = 7.07e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.599174
# D_KL = 0.018
# [BQRBM] epoch 56: β = 1.500, learning rate = 6.60e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.494419
# D_KL = 0.017
# [BQRBM] epoch 57: β = 1.500, learning rate = 6.16e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.691421
# D_KL = 0.021
# [BQRBM] epoch 58: β = 1.500, learning rate = 5.74e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.275078
# D_KL = 0.015
# [BQRBM] epoch 59: β = 1.500, learning rate = 5.36e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.497316
# D_KL = 0.016
# [BQRBM] epoch 60: β = 1.500, learning rate = 5.00e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.447584
# D_KL = 0.014
# [BQRBM] epoch 61: β = 1.500, learning rate = 4.67e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.451075
# D_KL = 0.016
# [BQRBM] epoch 62: β = 1.500, learning rate = 4.35e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.413813
# D_KL = 0.015
# [BQRBM] epoch 63: β = 1.500, learning rate = 4.06e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.781726
# D_KL = 0.014
# [BQRBM] epoch 64: β = 1.500, learning rate = 3.79e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.237915
# D_KL = 0.015
# [BQRBM] epoch 65: β = 1.500, learning rate = 3.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.450438
# D_KL = 0.017
# [BQRBM] epoch 66: β = 1.500, learning rate = 3.30e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.488486
# D_KL = 0.012
# [BQRBM] epoch 67: β = 1.500, learning rate = 3.08e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.616583
# D_KL = 0.013
# [BQRBM] epoch 68: β = 1.500, learning rate = 2.87e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.490548
# D_KL = 0.012
# [BQRBM] epoch 69: β = 1.500, learning rate = 2.68e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.604224
# D_KL = 0.016
# [BQRBM] epoch 70: β = 1.500, learning rate = 2.50e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.301702
# D_KL = 0.010
# [BQRBM] epoch 71: β = 1.500, learning rate = 2.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.731981
# D_KL = 0.011
# [BQRBM] epoch 72: β = 1.500, learning rate = 2.18e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.453572
# D_KL = 0.013
# [BQRBM] epoch 73: β = 1.500, learning rate = 2.03e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.555583
# D_KL = 0.013
# [BQRBM] epoch 74: β = 1.500, learning rate = 1.89e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.388302
# D_KL = 0.014
# [BQRBM] epoch 75: β = 1.500, learning rate = 1.77e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.182470
# D_KL = 0.014
# [BQRBM] epoch 76: β = 1.500, learning rate = 1.65e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.343385
# D_KL = 0.011
# [BQRBM] epoch 77: β = 1.500, learning rate = 1.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.661503
# D_KL = 0.011
# [BQRBM] epoch 78: β = 1.500, learning rate = 1.44e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.110741
# D_KL = 0.011
# [BQRBM] epoch 79: β = 1.500, learning rate = 1.34e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.719372
# D_KL = 0.014
# [BQRBM] epoch 80: β = 1.500, learning rate = 1.25e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.474008
# D_KL = 0.013
# [BQRBM] epoch 81: β = 1.500, learning rate = 1.17e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.569101
# D_KL = 0.011
# [BQRBM] epoch 82: β = 1.500, learning rate = 1.09e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.409569
# D_KL = 0.011
# [BQRBM] epoch 83: β = 1.500, learning rate = 1.02e-02, β learning rate = 0.00e+00, epoch duration = 0:00:22.399137
# D_KL = 0.015
# [BQRBM] epoch 84: β = 1.500, learning rate = 9.47e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.317989
# D_KL = 0.011
# [BQRBM] epoch 85: β = 1.500, learning rate = 8.84e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.680239
# D_KL = 0.010
# [BQRBM] epoch 86: β = 1.500, learning rate = 8.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.059509
# D_KL = 0.010
# [BQRBM] epoch 87: β = 1.500, learning rate = 7.69e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.314447
# D_KL = 0.015
# [BQRBM] epoch 88: β = 1.500, learning rate = 7.18e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.334914
# D_KL = 0.012
# [BQRBM] epoch 89: β = 1.500, learning rate = 6.70e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.258967
# D_KL = 0.011
# [BQRBM] epoch 90: β = 1.500, learning rate = 6.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.434103
# D_KL = 0.012
# [BQRBM] epoch 91: β = 1.500, learning rate = 5.83e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.343673
# D_KL = 0.010
# [BQRBM] epoch 92: β = 1.500, learning rate = 5.44e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.312528
# D_KL = 0.012
# [BQRBM] epoch 93: β = 1.500, learning rate = 5.08e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.431427
# D_KL = 0.012
# [BQRBM] epoch 94: β = 1.500, learning rate = 4.74e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.074914
# D_KL = 0.013
# [BQRBM] epoch 95: β = 1.500, learning rate = 4.42e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.211978
# D_KL = 0.016
# [BQRBM] epoch 96: β = 1.500, learning rate = 4.12e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.397162
# D_KL = 0.011
# [BQRBM] epoch 97: β = 1.500, learning rate = 3.85e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.301601
# D_KL = 0.012
# [BQRBM] epoch 98: β = 1.500, learning rate = 3.59e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.258730
# D_KL = 0.013
# [BQRBM] epoch 99: β = 1.500, learning rate = 3.35e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.327924
# D_KL = 0.013
# [BQRBM] epoch 100: β = 1.500, learning rate = 3.13e-03, β learning rate = 0.00e+00, epoch duration = 0:00:22.128814
# D_KL = 0.013
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# /tmp/ipykernel_29601/598832102.py in <module>
#      51             callback=callback,
#      52         )
# ---> 53         model.save(model_path)
#      54     else:
#      55         model = BQRBM.load(model_path)
#
# /private/cameron/thesis/src/qbm/models/BQRBM.py in save(self, file_path)
#     188             self.sampler = None
#     189
# --> 190         save_artifact(self, file_path)
#     191
#     192         if self.exact_params is None:
#
# /private/cameron/thesis/src/qbm/utils/misc.py in save_artifact(artifact, file_path)
#     219     elif file_path.suffix == ".pkl":
#     220         with open(file_path, "wb") as f:
# --> 221             pickle.dump(artifact, f)
#     222
#     223
#
# PicklingError: Can't pickle <class 'qbm.models.BQRBM.BQRBM'>: it's not the same object as qbm.models.BQRBM.BQRBM
# time: 37min 32s (started: 2022-02-24 12:21:41 +01:00)

# %%
model_paths = sorted(
    [
        f
        for f in (artifact_dir / "models").iterdir()
        if f.name.startswith("model_exact-s=")
    ]
)
models = [BQRBM.load(model_path) for model_path in model_paths]
# Out:
# time: 13.3 ms (started: 2022-01-31 17:26:45 +01:00)

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
import seaborn as sns

def smooth(x, k=10):
    x_out = np.zeros(len(x))
    for i in range(len(x)):
        x_out[i] = np.mean(x[i - min((k - 1, i)):i+1])
    return x_out

markers = ["o", "^", "v", "<", ">", "s", "p", "*", "P", "X", "+", "x"]
colors = [
    "tab:blue",
    "tab:orange",
    "tab:green",
    "tab:red",
    "tab:purple",
    "tab:brown",
    "tab:pink",
    "tab:gray",
    "tab:olive",
    "tab:cyan",
    "black",
    "gray",
]
# colors = sns.color_palette("magma", len(models))
s_betas = {s: beta for s, beta in zip(s_values, betas)}
for i, m in enumerate(models):
    dkls = [d["value"] for d in m.callback_outputs]
    print(m.anneal_params["s"], np.mean(dkls[-10:]))
    epochs = np.arange(1, len(dkls) + 1)
    ax.plot(
        epochs,
        smooth(dkls),
        label=fr"$s^* = {m.anneal_params['s']:.2f}$, $\beta_{{eff}} = {betas[::-1][i]:.2f}$",
        color=colors[i],
        marker=markers[i],
        markersize=8,
        markevery=3,
    )
ax.set_yticks(np.arange(0, 0.13, 0.02))
ax.set_ylim((0, 0.12))
ax.set_xlabel("Epoch")
ax.set_ylabel(r"$D_{KL}(p_{data} \ || \ p_{model})$ [10 Epoch Moving Average]")
ax.grid(True)
ax.legend()
plt.tight_layout()
plt.savefig(plot_dir / "dkl_exact_s_sweep.png")
