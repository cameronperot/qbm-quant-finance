# %% [markdown]
# # Exact QBM $s^*$ Comparison

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext autotime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import neptune.new as neptune
from scipy.constants import k as k_B, h as h_P

k_B /= h_P * 1e9

from qbm.utils import (
    binarize_df,
    convert_bin_list_to_str,
    get_binarization_params,
    get_project_dir,
    get_rng,
    kl_divergence,
    load_artifact,
    lr_exp_decay,
    prepare_training_data,
    save_artifact,
    unbinarize_df,
)
from qbm.models import BQRBM

# configure directories
project_dir = get_project_dir()
artifact_dir = project_dir / "artifacts/qbm/7x3"
if not artifact_dir.exists():
    artifact_dir.mkdir(parents=True)
plot_dir = project_dir / "results/plots/qbm/7x3"
if not plot_dir.exists():
    plot_dir.mkdir(parents=True)
    
# load anneal schedule
df_anneal = pd.read_csv(
    project_dir
    / "data/anneal_schedules/csv/09-1265A-A_Advantage_system5_1_annealing_schedule.csv",
    index_col="s",
)
if 0.5 not in df_anneal.index:
    df_anneal.loc[0.5] = (df_anneal.loc[0.499] + df_anneal.loc[0.501]) / 2
# Out:
# time: 1.35 s (started: 2022-01-31 17:26:44 +01:00)

# %% [markdown]
# ## Train Data Creation

# %%
seed = 42
n_visible = 7
n_hidden = 3
n_qubits = n_visible + n_hidden

rng = get_rng(seed)
n_samples = 1500
α = 2 / 3
N_1 = rng.normal(-2, 1, int(round(n_samples * α, 0)))
N_2 = rng.normal(3, 1, int(round(n_samples * (1 - α), 0)))
x = np.concatenate((N_1, N_2))

df = pd.DataFrame.from_dict({"x": x})
binarization_params = get_binarization_params(df, n_bits=n_visible)
df_binarized = binarize_df(df, binarization_params)
X_train = prepare_training_data(df_binarized)["X_train"]
# Out:
# time: 7.84 ms (started: 2022-01-31 17:26:45 +01:00)

# %%
def callback(model, sample_state_vectors):
    X_train = model.X_train
    n_visible = model.X_train.shape[1]
    train_states = (
        model._eigen_to_binary(model.X_train) * 2.0 ** np.arange(n_visible - 1, -1, -1)
    ).sum(axis=1)
    sample_states = (
        model._eigen_to_binary(sample_state_vectors[:, :n_visible])
        * 2.0 ** np.arange(n_visible - 1, -1, -1)
    ).sum(axis=1)

    dkl = kl_divergence(train_states, sample_states, n_bins=32)

    return {"value": dkl, "print": f"D_KL = {dkl:.3f}"}
# Out:
# time: 6.95 ms (started: 2022-01-31 17:26:45 +01:00)

# %% [markdown]
# ## Model Analysis (Exact)

# %%
# model params
embedding = None

# training params
n_epochs = 100
n_samples = 10_000
learning_rate = 0.1
mini_batch_size = 10
decay_epoch = 50
decay_period = 10
epochs = np.arange(1, n_epochs + 1)
learning_rates = learning_rate * lr_exp_decay(epochs, decay_epoch, decay_period)
learning_rates_beta = learning_rates
learning_rates_beta[:10] *= 5
learning_rates_beta[10:20] *= 2

train = True
s_values = np.round(np.arange(45, 105, 5) / 100, 2)[::-1]
betas = (1 / k_B / np.linspace(20e-3, 100e-3, len(s_values)))[::-1]
for i, s in enumerate(s_values):
    exact_params = {"beta": betas[i]}
    print(f"s = {s:.2f}, β = {betas[i]}")
    model_path = artifact_dir / f"models/model_exact-s={s:.2f}.pkl"
    if train:
        anneal_params = {
            "s": s,
            "A": df_anneal.loc[s, "A(s) (GHz)"],
            "B": df_anneal.loc[s, "B(s) (GHz)"],
        }
        # model init
        model = BQRBM(
            X_train=X_train,
            n_hidden=n_hidden,
            embedding=embedding,
            anneal_params=anneal_params,
            beta_initial=betas[i],
            beta_range=(1e-3, 10),
            exact_params=exact_params,
            seed=i,
        )

        # model train and save
        model.train(
            n_epochs=n_epochs,
            n_samples=n_samples,
            learning_rate=learning_rates,
            learning_rate_beta=0.0,
            mini_batch_size=mini_batch_size,
            callback=callback,
        )
        model.save(model_path)
    else:
        model = BQRBM.load(model_path)
# Out:
# s = 1.00, β = 0.47992430733662206
# [BQRBM] epoch 1: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150998
# 	D_KL = 0.074
# [BQRBM] epoch 2: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151356
# 	D_KL = 0.054
# [BQRBM] epoch 3: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.161377
# 	D_KL = 0.065
# [BQRBM] epoch 4: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.152241
# 	D_KL = 0.082
# [BQRBM] epoch 5: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150447
# 	D_KL = 0.092
# [BQRBM] epoch 6: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.159884
# 	D_KL = 0.043
# [BQRBM] epoch 7: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150216
# 	D_KL = 0.034
# [BQRBM] epoch 8: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.159128
# 	D_KL = 0.102
# [BQRBM] epoch 9: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.149952
# 	D_KL = 0.046
# [BQRBM] epoch 10: β = 0.480, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151986
# 	D_KL = 0.065
# [BQRBM] epoch 11: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150581
# 	D_KL = 0.019
# [BQRBM] epoch 12: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151655
# 	D_KL = 0.021
# [BQRBM] epoch 13: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150484
# 	D_KL = 0.019
# [BQRBM] epoch 14: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.154490
# 	D_KL = 0.017
# [BQRBM] epoch 15: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150519
# 	D_KL = 0.022
# [BQRBM] epoch 16: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.152702
# 	D_KL = 0.021
# [BQRBM] epoch 17: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.149897
# 	D_KL = 0.026
# [BQRBM] epoch 18: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.153094
# 	D_KL = 0.027
# [BQRBM] epoch 19: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150417
# 	D_KL = 0.020
# [BQRBM] epoch 20: β = 0.480, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151623
# 	D_KL = 0.027
# [BQRBM] epoch 21: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150286
# 	D_KL = 0.018
# [BQRBM] epoch 22: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151450
# 	D_KL = 0.016
# [BQRBM] epoch 23: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150220
# 	D_KL = 0.018
# [BQRBM] epoch 24: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.153082
# 	D_KL = 0.015
# [BQRBM] epoch 25: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.149949
# 	D_KL = 0.017
# [BQRBM] epoch 26: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.152943
# 	D_KL = 0.018
# [BQRBM] epoch 27: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150967
# 	D_KL = 0.013
# [BQRBM] epoch 28: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.152672
# 	D_KL = 0.013
# [BQRBM] epoch 29: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151127
# 	D_KL = 0.016
# [BQRBM] epoch 30: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151190
# 	D_KL = 0.012
# [BQRBM] epoch 31: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151497
# 	D_KL = 0.013
# [BQRBM] epoch 32: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150710
# 	D_KL = 0.019
# [BQRBM] epoch 33: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.152627
# 	D_KL = 0.014
# [BQRBM] epoch 34: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.151027
# 	D_KL = 0.018
# [BQRBM] epoch 35: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.153504
# 	D_KL = 0.027
# [BQRBM] epoch 36: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150624
# 	D_KL = 0.014
# [BQRBM] epoch 37: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150268
# 	D_KL = 0.013
# [BQRBM] epoch 38: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.153766
# 	D_KL = 0.015
# [BQRBM] epoch 39: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.153733
# 	D_KL = 0.017
# [BQRBM] epoch 40: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.155323
# 	D_KL = 0.013
# [BQRBM] epoch 41: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.153938
# 	D_KL = 0.017
# [BQRBM] epoch 42: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.153883
# 	D_KL = 0.016
# [BQRBM] epoch 43: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.156207
# 	D_KL = 0.015
# [BQRBM] epoch 44: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.164997
# 	D_KL = 0.013
# [BQRBM] epoch 45: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.181684
# 	D_KL = 0.013
# [BQRBM] epoch 46: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.174532
# 	D_KL = 0.015
# [BQRBM] epoch 47: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.158301
# 	D_KL = 0.015
# [BQRBM] epoch 48: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.172294
# 	D_KL = 0.017
# [BQRBM] epoch 49: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.150434
# 	D_KL = 0.011
# [BQRBM] epoch 50: β = 0.480, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:00.149512
# 	D_KL = 0.010
# [BQRBM] epoch 51: β = 0.480, learning rate = 9.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.150128
# 	D_KL = 0.015
# [BQRBM] epoch 52: β = 0.480, learning rate = 8.71e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.150288
# 	D_KL = 0.011
# [BQRBM] epoch 53: β = 0.480, learning rate = 8.12e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148829
# 	D_KL = 0.014
# [BQRBM] epoch 54: β = 0.480, learning rate = 7.58e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.154698
# 	D_KL = 0.011
# [BQRBM] epoch 55: β = 0.480, learning rate = 7.07e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148979
# 	D_KL = 0.016
# [BQRBM] epoch 56: β = 0.480, learning rate = 6.60e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.154909
# 	D_KL = 0.015
# [BQRBM] epoch 57: β = 0.480, learning rate = 6.16e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.147975
# 	D_KL = 0.019
# [BQRBM] epoch 58: β = 0.480, learning rate = 5.74e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.154400
# 	D_KL = 0.013
# [BQRBM] epoch 59: β = 0.480, learning rate = 5.36e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149246
# 	D_KL = 0.013
# [BQRBM] epoch 60: β = 0.480, learning rate = 5.00e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149237
# 	D_KL = 0.011
# [BQRBM] epoch 61: β = 0.480, learning rate = 4.67e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148481
# 	D_KL = 0.015
# [BQRBM] epoch 62: β = 0.480, learning rate = 4.35e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149040
# 	D_KL = 0.013
# [BQRBM] epoch 63: β = 0.480, learning rate = 4.06e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.152899
# 	D_KL = 0.013
# [BQRBM] epoch 64: β = 0.480, learning rate = 3.79e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149489
# 	D_KL = 0.013
# [BQRBM] epoch 65: β = 0.480, learning rate = 3.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.153607
# 	D_KL = 0.016
# [BQRBM] epoch 66: β = 0.480, learning rate = 3.30e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148951
# 	D_KL = 0.010
# [BQRBM] epoch 67: β = 0.480, learning rate = 3.08e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.153891
# 	D_KL = 0.011
# [BQRBM] epoch 68: β = 0.480, learning rate = 2.87e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148494
# 	D_KL = 0.011
# [BQRBM] epoch 69: β = 0.480, learning rate = 2.68e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149523
# 	D_KL = 0.015
# [BQRBM] epoch 70: β = 0.480, learning rate = 2.50e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149181
# 	D_KL = 0.010
# [BQRBM] epoch 71: β = 0.480, learning rate = 2.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148695
# 	D_KL = 0.010
# [BQRBM] epoch 72: β = 0.480, learning rate = 2.18e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.152815
# 	D_KL = 0.011
# [BQRBM] epoch 73: β = 0.480, learning rate = 2.03e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149114
# 	D_KL = 0.011
# [BQRBM] epoch 74: β = 0.480, learning rate = 1.89e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.153958
# 	D_KL = 0.012
# [BQRBM] epoch 75: β = 0.480, learning rate = 1.77e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149064
# 	D_KL = 0.013
# [BQRBM] epoch 76: β = 0.480, learning rate = 1.65e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.153277
# 	D_KL = 0.009
# [BQRBM] epoch 77: β = 0.480, learning rate = 1.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148760
# 	D_KL = 0.011
# [BQRBM] epoch 78: β = 0.480, learning rate = 1.44e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149697
# 	D_KL = 0.009
# [BQRBM] epoch 79: β = 0.480, learning rate = 1.34e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.148884
# 	D_KL = 0.011
# [BQRBM] epoch 80: β = 0.480, learning rate = 1.25e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149658
# 	D_KL = 0.012
# [BQRBM] epoch 81: β = 0.480, learning rate = 1.17e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.147871
# 	D_KL = 0.009
# [BQRBM] epoch 82: β = 0.480, learning rate = 1.09e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.154138
# 	D_KL = 0.011
# [BQRBM] epoch 83: β = 0.480, learning rate = 1.02e-02, β learning rate = 0.00e+00, epoch duration = 0:00:00.149480
# 	D_KL = 0.012
# [BQRBM] epoch 84: β = 0.480, learning rate = 9.47e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.153420
# 	D_KL = 0.009
# [BQRBM] epoch 85: β = 0.480, learning rate = 8.84e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.151612
# 	D_KL = 0.009
# [BQRBM] epoch 86: β = 0.480, learning rate = 8.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.150653
# 	D_KL = 0.009
# [BQRBM] epoch 87: β = 0.480, learning rate = 7.69e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.148990
# 	D_KL = 0.013
# [BQRBM] epoch 88: β = 0.480, learning rate = 7.18e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.148698
# 	D_KL = 0.011
# [BQRBM] epoch 89: β = 0.480, learning rate = 6.70e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.151020
# 	D_KL = 0.010
# [BQRBM] epoch 90: β = 0.480, learning rate = 6.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.148831
# 	D_KL = 0.010
# [BQRBM] epoch 91: β = 0.480, learning rate = 5.83e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.153362
# 	D_KL = 0.009
# [BQRBM] epoch 92: β = 0.480, learning rate = 5.44e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.149487
# 	D_KL = 0.010
# [BQRBM] epoch 93: β = 0.480, learning rate = 5.08e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.154292
# 	D_KL = 0.011
# [BQRBM] epoch 94: β = 0.480, learning rate = 4.74e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.149008
# 	D_KL = 0.010
# [BQRBM] epoch 95: β = 0.480, learning rate = 4.42e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.153792
# 	D_KL = 0.015
# [BQRBM] epoch 96: β = 0.480, learning rate = 4.12e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.148388
# 	D_KL = 0.009
# [BQRBM] epoch 97: β = 0.480, learning rate = 3.85e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.149332
# 	D_KL = 0.010
# [BQRBM] epoch 98: β = 0.480, learning rate = 3.59e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.148915
# 	D_KL = 0.011
# [BQRBM] epoch 99: β = 0.480, learning rate = 3.35e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.149681
# 	D_KL = 0.010
# [BQRBM] epoch 100: β = 0.480, learning rate = 3.13e-03, β learning rate = 0.00e+00, epoch duration = 0:00:00.151949
# 	D_KL = 0.012
# s = 0.95, β = 0.5175654294806709
# [BQRBM] epoch 1: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:20.336057
# 	D_KL = 0.113
# [BQRBM] epoch 2: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.963885
# 	D_KL = 0.069
# [BQRBM] epoch 3: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:20.168160
# 	D_KL = 0.067
# [BQRBM] epoch 4: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:20.161176
# 	D_KL = 0.063
# [BQRBM] epoch 5: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.812557
# 	D_KL = 0.050
# [BQRBM] epoch 6: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.853477
# 	D_KL = 0.029
# [BQRBM] epoch 7: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.748374
# 	D_KL = 0.031
# [BQRBM] epoch 8: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.668088
# 	D_KL = 0.051
# [BQRBM] epoch 9: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.948629
# 	D_KL = 0.040
# [BQRBM] epoch 10: β = 0.518, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.613449
# 	D_KL = 0.039
# [BQRBM] epoch 11: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.675360
# 	D_KL = 0.023
# [BQRBM] epoch 12: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.617258
# 	D_KL = 0.020
# [BQRBM] epoch 13: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.817357
# 	D_KL = 0.019
# [BQRBM] epoch 14: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.645970
# 	D_KL = 0.022
# [BQRBM] epoch 15: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.572275
# 	D_KL = 0.019
# [BQRBM] epoch 16: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.943538
# 	D_KL = 0.022
# [BQRBM] epoch 17: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.622244
# 	D_KL = 0.019
# [BQRBM] epoch 18: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.862663
# 	D_KL = 0.018
# [BQRBM] epoch 19: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.781887
# 	D_KL = 0.024
# [BQRBM] epoch 20: β = 0.518, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.644887
# 	D_KL = 0.030
# [BQRBM] epoch 21: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.800467
# 	D_KL = 0.022
# [BQRBM] epoch 22: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.679125
# 	D_KL = 0.020
# [BQRBM] epoch 23: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.619674
# 	D_KL = 0.014
# [BQRBM] epoch 24: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.574693
# 	D_KL = 0.019
# [BQRBM] epoch 25: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.824247
# 	D_KL = 0.017
# [BQRBM] epoch 26: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.676132
# 	D_KL = 0.018
# [BQRBM] epoch 27: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.526479
# 	D_KL = 0.022
# [BQRBM] epoch 28: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.763709
# 	D_KL = 0.018
# [BQRBM] epoch 29: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.650873
# 	D_KL = 0.018
# [BQRBM] epoch 30: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.943402
# 	D_KL = 0.013
# [BQRBM] epoch 31: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.761722
# 	D_KL = 0.018
# [BQRBM] epoch 32: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.751095
# 	D_KL = 0.014
# [BQRBM] epoch 33: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.553434
# 	D_KL = 0.015
# [BQRBM] epoch 34: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.607611
# 	D_KL = 0.015
# [BQRBM] epoch 35: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.859711
# 	D_KL = 0.020
# [BQRBM] epoch 36: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.600906
# 	D_KL = 0.016
# [BQRBM] epoch 37: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.701811
# 	D_KL = 0.029
# [BQRBM] epoch 38: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.824888
# 	D_KL = 0.025
# [BQRBM] epoch 39: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.697709
# 	D_KL = 0.015
# [BQRBM] epoch 40: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.741514
# 	D_KL = 0.018
# [BQRBM] epoch 41: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.773086
# 	D_KL = 0.017
# [BQRBM] epoch 42: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.918624
# 	D_KL = 0.013
# [BQRBM] epoch 43: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.595465
# 	D_KL = 0.013
# [BQRBM] epoch 44: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.799190
# 	D_KL = 0.013
# [BQRBM] epoch 45: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.543124
# 	D_KL = 0.013
# [BQRBM] epoch 46: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.510854
# 	D_KL = 0.021
# [BQRBM] epoch 47: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.785472
# 	D_KL = 0.014
# [BQRBM] epoch 48: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.743851
# 	D_KL = 0.016
# [BQRBM] epoch 49: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.639079
# 	D_KL = 0.021
# [BQRBM] epoch 50: β = 0.518, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.765516
# 	D_KL = 0.020
# [BQRBM] epoch 51: β = 0.518, learning rate = 9.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.701142
# 	D_KL = 0.021
# [BQRBM] epoch 52: β = 0.518, learning rate = 8.71e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.449535
# 	D_KL = 0.020
# [BQRBM] epoch 53: β = 0.518, learning rate = 8.12e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.655495
# 	D_KL = 0.014
# [BQRBM] epoch 54: β = 0.518, learning rate = 7.58e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.508050
# 	D_KL = 0.014
# [BQRBM] epoch 55: β = 0.518, learning rate = 7.07e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.415324
# 	D_KL = 0.017
# [BQRBM] epoch 56: β = 0.518, learning rate = 6.60e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.648551
# 	D_KL = 0.012
# [BQRBM] epoch 57: β = 0.518, learning rate = 6.16e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.655701
# 	D_KL = 0.010
# [BQRBM] epoch 58: β = 0.518, learning rate = 5.74e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.785254
# 	D_KL = 0.018
# [BQRBM] epoch 59: β = 0.518, learning rate = 5.36e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.612318
# 	D_KL = 0.019
# [BQRBM] epoch 60: β = 0.518, learning rate = 5.00e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.762156
# 	D_KL = 0.013
# [BQRBM] epoch 61: β = 0.518, learning rate = 4.67e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.528059
# 	D_KL = 0.013
# [BQRBM] epoch 62: β = 0.518, learning rate = 4.35e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.545274
# 	D_KL = 0.016
# [BQRBM] epoch 63: β = 0.518, learning rate = 4.06e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.760602
# 	D_KL = 0.014
# [BQRBM] epoch 64: β = 0.518, learning rate = 3.79e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.530838
# 	D_KL = 0.011
# [BQRBM] epoch 65: β = 0.518, learning rate = 3.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.682439
# 	D_KL = 0.016
# [BQRBM] epoch 66: β = 0.518, learning rate = 3.30e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.686208
# 	D_KL = 0.013
# [BQRBM] epoch 67: β = 0.518, learning rate = 3.08e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.669544
# 	D_KL = 0.011
# [BQRBM] epoch 68: β = 0.518, learning rate = 2.87e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.651316
# 	D_KL = 0.014
# [BQRBM] epoch 69: β = 0.518, learning rate = 2.68e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.638569
# 	D_KL = 0.014
# [BQRBM] epoch 70: β = 0.518, learning rate = 2.50e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.849894
# 	D_KL = 0.013
# [BQRBM] epoch 71: β = 0.518, learning rate = 2.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.562168
# 	D_KL = 0.014
# [BQRBM] epoch 72: β = 0.518, learning rate = 2.18e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.749662
# 	D_KL = 0.016
# [BQRBM] epoch 73: β = 0.518, learning rate = 2.03e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.499160
# 	D_KL = 0.014
# [BQRBM] epoch 74: β = 0.518, learning rate = 1.89e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.656527
# 	D_KL = 0.014
# [BQRBM] epoch 75: β = 0.518, learning rate = 1.77e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.719797
# 	D_KL = 0.016
# [BQRBM] epoch 76: β = 0.518, learning rate = 1.65e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.684567
# 	D_KL = 0.010
# [BQRBM] epoch 77: β = 0.518, learning rate = 1.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.662048
# 	D_KL = 0.014
# [BQRBM] epoch 78: β = 0.518, learning rate = 1.44e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.609743
# 	D_KL = 0.012
# [BQRBM] epoch 79: β = 0.518, learning rate = 1.34e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.601034
# 	D_KL = 0.011
# [BQRBM] epoch 80: β = 0.518, learning rate = 1.25e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.727634
# 	D_KL = 0.013
# [BQRBM] epoch 81: β = 0.518, learning rate = 1.17e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.649043
# 	D_KL = 0.012
# [BQRBM] epoch 82: β = 0.518, learning rate = 1.09e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.823798
# 	D_KL = 0.015
# [BQRBM] epoch 83: β = 0.518, learning rate = 1.02e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.521900
# 	D_KL = 0.012
# [BQRBM] epoch 84: β = 0.518, learning rate = 9.47e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.563793
# 	D_KL = 0.013
# [BQRBM] epoch 85: β = 0.518, learning rate = 8.84e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.859664
# 	D_KL = 0.015
# [BQRBM] epoch 86: β = 0.518, learning rate = 8.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.753097
# 	D_KL = 0.013
# [BQRBM] epoch 87: β = 0.518, learning rate = 7.69e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.492658
# 	D_KL = 0.016
# [BQRBM] epoch 88: β = 0.518, learning rate = 7.18e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.644068
# 	D_KL = 0.016
# [BQRBM] epoch 89: β = 0.518, learning rate = 6.70e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.591980
# 	D_KL = 0.013
# [BQRBM] epoch 90: β = 0.518, learning rate = 6.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.550088
# 	D_KL = 0.016
# [BQRBM] epoch 91: β = 0.518, learning rate = 5.83e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.730000
# 	D_KL = 0.012
# [BQRBM] epoch 92: β = 0.518, learning rate = 5.44e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.614948
# 	D_KL = 0.016
# [BQRBM] epoch 93: β = 0.518, learning rate = 5.08e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.880787
# 	D_KL = 0.014
# [BQRBM] epoch 94: β = 0.518, learning rate = 4.74e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.928748
# 	D_KL = 0.011
# [BQRBM] epoch 95: β = 0.518, learning rate = 4.42e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.852254
# 	D_KL = 0.011
# [BQRBM] epoch 96: β = 0.518, learning rate = 4.12e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.702777
# 	D_KL = 0.015
# [BQRBM] epoch 97: β = 0.518, learning rate = 3.85e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.744464
# 	D_KL = 0.009
# [BQRBM] epoch 98: β = 0.518, learning rate = 3.59e-03, β learning rate = 0.00e+00, epoch duration = 0:00:20.176743
# 	D_KL = 0.017
# [BQRBM] epoch 99: β = 0.518, learning rate = 3.35e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.662702
# 	D_KL = 0.013
# [BQRBM] epoch 100: β = 0.518, learning rate = 3.13e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.623589
# 	D_KL = 0.013
# s = 0.90, β = 0.5616135511386002
# [BQRBM] epoch 1: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:20.274094
# 	D_KL = 0.088
# [BQRBM] epoch 2: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.915414
# 	D_KL = 0.103
# [BQRBM] epoch 3: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.844874
# 	D_KL = 0.073
# [BQRBM] epoch 4: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.844611
# 	D_KL = 0.036
# [BQRBM] epoch 5: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.801068
# 	D_KL = 0.057
# [BQRBM] epoch 6: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.730066
# 	D_KL = 0.053
# [BQRBM] epoch 7: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.767911
# 	D_KL = 0.032
# [BQRBM] epoch 8: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.769624
# 	D_KL = 0.074
# [BQRBM] epoch 9: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.559389
# 	D_KL = 0.039
# [BQRBM] epoch 10: β = 0.562, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.725771
# 	D_KL = 0.058
# [BQRBM] epoch 11: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.324538
# 	D_KL = 0.021
# [BQRBM] epoch 12: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.315452
# 	D_KL = 0.025
# [BQRBM] epoch 13: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.574097
# 	D_KL = 0.017
# [BQRBM] epoch 14: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.334078
# 	D_KL = 0.033
# [BQRBM] epoch 15: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.415616
# 	D_KL = 0.019
# [BQRBM] epoch 16: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.353623
# 	D_KL = 0.024
# [BQRBM] epoch 17: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.507499
# 	D_KL = 0.019
# [BQRBM] epoch 18: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.407478
# 	D_KL = 0.024
# [BQRBM] epoch 19: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.269414
# 	D_KL = 0.025
# [BQRBM] epoch 20: β = 0.562, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.284136
# 	D_KL = 0.017
# [BQRBM] epoch 21: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.192793
# 	D_KL = 0.018
# [BQRBM] epoch 22: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.268602
# 	D_KL = 0.020
# [BQRBM] epoch 23: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.501479
# 	D_KL = 0.018
# [BQRBM] epoch 24: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.196896
# 	D_KL = 0.016
# [BQRBM] epoch 25: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.342322
# 	D_KL = 0.025
# [BQRBM] epoch 26: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.223066
# 	D_KL = 0.014
# [BQRBM] epoch 27: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.480797
# 	D_KL = 0.017
# [BQRBM] epoch 28: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.216430
# 	D_KL = 0.024
# [BQRBM] epoch 29: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.254229
# 	D_KL = 0.021
# [BQRBM] epoch 30: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.254582
# 	D_KL = 0.017
# [BQRBM] epoch 31: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.308482
# 	D_KL = 0.014
# [BQRBM] epoch 32: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.354968
# 	D_KL = 0.020
# [BQRBM] epoch 33: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.424629
# 	D_KL = 0.014
# [BQRBM] epoch 34: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.262105
# 	D_KL = 0.015
# [BQRBM] epoch 35: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.350186
# 	D_KL = 0.016
# [BQRBM] epoch 36: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.354433
# 	D_KL = 0.017
# [BQRBM] epoch 37: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.204980
# 	D_KL = 0.012
# [BQRBM] epoch 38: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.377353
# 	D_KL = 0.016
# [BQRBM] epoch 39: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.417588
# 	D_KL = 0.012
# [BQRBM] epoch 40: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.559264
# 	D_KL = 0.013
# [BQRBM] epoch 41: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.208756
# 	D_KL = 0.010
# [BQRBM] epoch 42: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.449342
# 	D_KL = 0.014
# [BQRBM] epoch 43: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.245115
# 	D_KL = 0.014
# [BQRBM] epoch 44: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.339880
# 	D_KL = 0.013
# [BQRBM] epoch 45: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.468643
# 	D_KL = 0.014
# [BQRBM] epoch 46: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.348301
# 	D_KL = 0.015
# [BQRBM] epoch 47: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.374458
# 	D_KL = 0.016
# [BQRBM] epoch 48: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.291259
# 	D_KL = 0.024
# [BQRBM] epoch 49: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.433273
# 	D_KL = 0.016
# [BQRBM] epoch 50: β = 0.562, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.398607
# 	D_KL = 0.013
# [BQRBM] epoch 51: β = 0.562, learning rate = 9.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.201631
# 	D_KL = 0.013
# [BQRBM] epoch 52: β = 0.562, learning rate = 8.71e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.484862
# 	D_KL = 0.016
# [BQRBM] epoch 53: β = 0.562, learning rate = 8.12e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.206840
# 	D_KL = 0.019
# [BQRBM] epoch 54: β = 0.562, learning rate = 7.58e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.337317
# 	D_KL = 0.011
# [BQRBM] epoch 55: β = 0.562, learning rate = 7.07e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.616003
# 	D_KL = 0.018
# [BQRBM] epoch 56: β = 0.562, learning rate = 6.60e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.229084
# 	D_KL = 0.014
# [BQRBM] epoch 57: β = 0.562, learning rate = 6.16e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.294156
# 	D_KL = 0.010
# [BQRBM] epoch 58: β = 0.562, learning rate = 5.74e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.326031
# 	D_KL = 0.014
# [BQRBM] epoch 59: β = 0.562, learning rate = 5.36e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.204064
# 	D_KL = 0.012
# [BQRBM] epoch 60: β = 0.562, learning rate = 5.00e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.317586
# 	D_KL = 0.012
# [BQRBM] epoch 61: β = 0.562, learning rate = 4.67e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.369982
# 	D_KL = 0.012
# [BQRBM] epoch 62: β = 0.562, learning rate = 4.35e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.316981
# 	D_KL = 0.014
# [BQRBM] epoch 63: β = 0.562, learning rate = 4.06e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.245129
# 	D_KL = 0.012
# [BQRBM] epoch 64: β = 0.562, learning rate = 3.79e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.416138
# 	D_KL = 0.012
# [BQRBM] epoch 65: β = 0.562, learning rate = 3.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.328292
# 	D_KL = 0.012
# [BQRBM] epoch 66: β = 0.562, learning rate = 3.30e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.293237
# 	D_KL = 0.012
# [BQRBM] epoch 67: β = 0.562, learning rate = 3.08e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.602299
# 	D_KL = 0.010
# [BQRBM] epoch 68: β = 0.562, learning rate = 2.87e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.464046
# 	D_KL = 0.013
# [BQRBM] epoch 69: β = 0.562, learning rate = 2.68e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.414241
# 	D_KL = 0.011
# [BQRBM] epoch 70: β = 0.562, learning rate = 2.50e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.238945
# 	D_KL = 0.015
# [BQRBM] epoch 71: β = 0.562, learning rate = 2.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.367290
# 	D_KL = 0.009
# [BQRBM] epoch 72: β = 0.562, learning rate = 2.18e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.296601
# 	D_KL = 0.013
# [BQRBM] epoch 73: β = 0.562, learning rate = 2.03e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.253016
# 	D_KL = 0.011
# [BQRBM] epoch 74: β = 0.562, learning rate = 1.89e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.473679
# 	D_KL = 0.012
# [BQRBM] epoch 75: β = 0.562, learning rate = 1.77e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.182675
# 	D_KL = 0.011
# [BQRBM] epoch 76: β = 0.562, learning rate = 1.65e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.325509
# 	D_KL = 0.014
# [BQRBM] epoch 77: β = 0.562, learning rate = 1.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.336369
# 	D_KL = 0.009
# [BQRBM] epoch 78: β = 0.562, learning rate = 1.44e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.156859
# 	D_KL = 0.009
# [BQRBM] epoch 79: β = 0.562, learning rate = 1.34e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.368257
# 	D_KL = 0.010
# [BQRBM] epoch 80: β = 0.562, learning rate = 1.25e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.537263
# 	D_KL = 0.011
# [BQRBM] epoch 81: β = 0.562, learning rate = 1.17e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.674331
# 	D_KL = 0.010
# [BQRBM] epoch 82: β = 0.562, learning rate = 1.09e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.331395
# 	D_KL = 0.011
# [BQRBM] epoch 83: β = 0.562, learning rate = 1.02e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.330354
# 	D_KL = 0.011
# [BQRBM] epoch 84: β = 0.562, learning rate = 9.47e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.336901
# 	D_KL = 0.012
# [BQRBM] epoch 85: β = 0.562, learning rate = 8.84e-03, β learning rate = 0.00e+00, epoch duration = 0:00:18.945541
# 	D_KL = 0.009
# [BQRBM] epoch 86: β = 0.562, learning rate = 8.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.210629
# 	D_KL = 0.011
# [BQRBM] epoch 87: β = 0.562, learning rate = 7.69e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.385163
# 	D_KL = 0.010
# [BQRBM] epoch 88: β = 0.562, learning rate = 7.18e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.204998
# 	D_KL = 0.011
# [BQRBM] epoch 89: β = 0.562, learning rate = 6.70e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.145660
# 	D_KL = 0.010
# [BQRBM] epoch 90: β = 0.562, learning rate = 6.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.240611
# 	D_KL = 0.009
# [BQRBM] epoch 91: β = 0.562, learning rate = 5.83e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.258491
# 	D_KL = 0.012
# [BQRBM] epoch 92: β = 0.562, learning rate = 5.44e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.239832
# 	D_KL = 0.010
# [BQRBM] epoch 93: β = 0.562, learning rate = 5.08e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.071977
# 	D_KL = 0.011
# [BQRBM] epoch 94: β = 0.562, learning rate = 4.74e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.054814
# 	D_KL = 0.010
# [BQRBM] epoch 95: β = 0.562, learning rate = 4.42e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.260110
# 	D_KL = 0.010
# [BQRBM] epoch 96: β = 0.562, learning rate = 4.12e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.086720
# 	D_KL = 0.010
# [BQRBM] epoch 97: β = 0.562, learning rate = 3.85e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.361159
# 	D_KL = 0.009
# [BQRBM] epoch 98: β = 0.562, learning rate = 3.59e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.104675
# 	D_KL = 0.012
# [BQRBM] epoch 99: β = 0.562, learning rate = 3.35e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.170469
# 	D_KL = 0.009
# [BQRBM] epoch 100: β = 0.562, learning rate = 3.13e-03, β learning rate = 0.00e+00, epoch duration = 0:00:19.086442
# 	D_KL = 0.010
# s = 0.85, β = 0.6138566721747492
# [BQRBM] epoch 1: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:20.173651
# 	D_KL = 0.084
# [BQRBM] epoch 2: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.530223
# 	D_KL = 0.071
# [BQRBM] epoch 3: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.679311
# 	D_KL = 0.099
# [BQRBM] epoch 4: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.564402
# 	D_KL = 0.043
# [BQRBM] epoch 5: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.476804
# 	D_KL = 0.079
# [BQRBM] epoch 6: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.501094
# 	D_KL = 0.047
# [BQRBM] epoch 7: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.407258
# 	D_KL = 0.051
# [BQRBM] epoch 8: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.437723
# 	D_KL = 0.106
# [BQRBM] epoch 9: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.321344
# 	D_KL = 0.042
# [BQRBM] epoch 10: β = 0.614, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.386099
# 	D_KL = 0.030
# [BQRBM] epoch 11: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.172580
# 	D_KL = 0.018
# [BQRBM] epoch 12: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.209713
# 	D_KL = 0.025
# [BQRBM] epoch 13: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.298528
# 	D_KL = 0.016
# [BQRBM] epoch 14: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.172572
# 	D_KL = 0.025
# [BQRBM] epoch 15: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.169023
# 	D_KL = 0.033
# [BQRBM] epoch 16: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.378616
# 	D_KL = 0.021
# [BQRBM] epoch 17: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.187711
# 	D_KL = 0.023
# [BQRBM] epoch 18: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.168287
# 	D_KL = 0.026
# [BQRBM] epoch 19: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.305162
# 	D_KL = 0.017
# [BQRBM] epoch 20: β = 0.614, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.138335
# 	D_KL = 0.021
# [BQRBM] epoch 21: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.222107
# 	D_KL = 0.021
# [BQRBM] epoch 22: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.222029
# 	D_KL = 0.017
# [BQRBM] epoch 23: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.177988
# 	D_KL = 0.017
# [BQRBM] epoch 24: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.179014
# 	D_KL = 0.021
# [BQRBM] epoch 25: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.140666
# 	D_KL = 0.014
# [BQRBM] epoch 26: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.253651
# 	D_KL = 0.021
# [BQRBM] epoch 27: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.183225
# 	D_KL = 0.017
# [BQRBM] epoch 28: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.127745
# 	D_KL = 0.017
# [BQRBM] epoch 29: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.226469
# 	D_KL = 0.016
# [BQRBM] epoch 30: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.143930
# 	D_KL = 0.014
# [BQRBM] epoch 31: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.179722
# 	D_KL = 0.020
# [BQRBM] epoch 32: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.190745
# 	D_KL = 0.019
# [BQRBM] epoch 33: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.121835
# 	D_KL = 0.016
# [BQRBM] epoch 34: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.129457
# 	D_KL = 0.017
# [BQRBM] epoch 35: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.043147
# 	D_KL = 0.015
# [BQRBM] epoch 36: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.291959
# 	D_KL = 0.013
# [BQRBM] epoch 37: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.119441
# 	D_KL = 0.020
# [BQRBM] epoch 38: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.161931
# 	D_KL = 0.014
# [BQRBM] epoch 39: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.275650
# 	D_KL = 0.015
# [BQRBM] epoch 40: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.223640
# 	D_KL = 0.014
# [BQRBM] epoch 41: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.181501
# 	D_KL = 0.014
# [BQRBM] epoch 42: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.320882
# 	D_KL = 0.018
# [BQRBM] epoch 43: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.155091
# 	D_KL = 0.014
# [BQRBM] epoch 44: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.166258
# 	D_KL = 0.024
# [BQRBM] epoch 45: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.317235
# 	D_KL = 0.018
# [BQRBM] epoch 46: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.197851
# 	D_KL = 0.015
# [BQRBM] epoch 47: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.179501
# 	D_KL = 0.022
# [BQRBM] epoch 48: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:19.785567
# 	D_KL = 0.016
# [BQRBM] epoch 49: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:20.059564
# 	D_KL = 0.015
# [BQRBM] epoch 50: β = 0.614, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:20.066214
# 	D_KL = 0.015
# [BQRBM] epoch 51: β = 0.614, learning rate = 9.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.877378
# 	D_KL = 0.015
# [BQRBM] epoch 52: β = 0.614, learning rate = 8.71e-02, β learning rate = 0.00e+00, epoch duration = 0:00:20.346923
# 	D_KL = 0.014
# [BQRBM] epoch 53: β = 0.614, learning rate = 8.12e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.221152
# 	D_KL = 0.015
# [BQRBM] epoch 54: β = 0.614, learning rate = 7.58e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.359688
# 	D_KL = 0.012
# [BQRBM] epoch 55: β = 0.614, learning rate = 7.07e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.327216
# 	D_KL = 0.019
# [BQRBM] epoch 56: β = 0.614, learning rate = 6.60e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.219669
# 	D_KL = 0.012
# [BQRBM] epoch 57: β = 0.614, learning rate = 6.16e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.214724
# 	D_KL = 0.014
# [BQRBM] epoch 58: β = 0.614, learning rate = 5.74e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.324664
# 	D_KL = 0.013
# [BQRBM] epoch 59: β = 0.614, learning rate = 5.36e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.223845
# 	D_KL = 0.019
# [BQRBM] epoch 60: β = 0.614, learning rate = 5.00e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.269258
# 	D_KL = 0.015
# [BQRBM] epoch 61: β = 0.614, learning rate = 4.67e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.337510
# 	D_KL = 0.012
# [BQRBM] epoch 62: β = 0.614, learning rate = 4.35e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.155306
# 	D_KL = 0.019
# [BQRBM] epoch 63: β = 0.614, learning rate = 4.06e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.160730
# 	D_KL = 0.012
# [BQRBM] epoch 64: β = 0.614, learning rate = 3.79e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.271641
# 	D_KL = 0.013
# [BQRBM] epoch 65: β = 0.614, learning rate = 3.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.148307
# 	D_KL = 0.014
# [BQRBM] epoch 66: β = 0.614, learning rate = 3.30e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.235731
# 	D_KL = 0.012
# [BQRBM] epoch 67: β = 0.614, learning rate = 3.08e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.186381
# 	D_KL = 0.015
# [BQRBM] epoch 68: β = 0.614, learning rate = 2.87e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.198558
# 	D_KL = 0.014
# [BQRBM] epoch 69: β = 0.614, learning rate = 2.68e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.187148
# 	D_KL = 0.014
# [BQRBM] epoch 70: β = 0.614, learning rate = 2.50e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.079787
# 	D_KL = 0.010
# [BQRBM] epoch 71: β = 0.614, learning rate = 2.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:19.260580
# 	D_KL = 0.014
# ...
# 	D_KL = 0.012
# [BQRBM] epoch 78: β = 1.760, learning rate = 1.44e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.832844
# 	D_KL = 0.011
# [BQRBM] epoch 79: β = 1.760, learning rate = 1.34e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.838491
# 	D_KL = 0.013
# [BQRBM] epoch 80: β = 1.760, learning rate = 1.25e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.675583
# 	D_KL = 0.011
# [BQRBM] epoch 81: β = 1.760, learning rate = 1.17e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.448025
# 	D_KL = 0.011
# [BQRBM] epoch 82: β = 1.760, learning rate = 1.09e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.988193
# 	D_KL = 0.011
# [BQRBM] epoch 83: β = 1.760, learning rate = 1.02e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.544561
# 	D_KL = 0.012
# [BQRBM] epoch 84: β = 1.760, learning rate = 9.47e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.378311
# 	D_KL = 0.013
# [BQRBM] epoch 85: β = 1.760, learning rate = 8.84e-03, β learning rate = 0.00e+00, epoch duration = 0:00:30.554839
# 	D_KL = 0.012
# [BQRBM] epoch 86: β = 1.760, learning rate = 8.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.029643
# 	D_KL = 0.011
# [BQRBM] epoch 87: β = 1.760, learning rate = 7.69e-03, β learning rate = 0.00e+00, epoch duration = 0:00:30.954252
# 	D_KL = 0.013
# [BQRBM] epoch 88: β = 1.760, learning rate = 7.18e-03, β learning rate = 0.00e+00, epoch duration = 0:00:30.575141
# 	D_KL = 0.011
# [BQRBM] epoch 89: β = 1.760, learning rate = 6.70e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.688133
# 	D_KL = 0.010
# [BQRBM] epoch 90: β = 1.760, learning rate = 6.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:30.834471
# 	D_KL = 0.011
# [BQRBM] epoch 91: β = 1.760, learning rate = 5.83e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.056854
# 	D_KL = 0.013
# [BQRBM] epoch 92: β = 1.760, learning rate = 5.44e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.337492
# 	D_KL = 0.010
# [BQRBM] epoch 93: β = 1.760, learning rate = 5.08e-03, β learning rate = 0.00e+00, epoch duration = 0:00:30.772114
# 	D_KL = 0.012
# [BQRBM] epoch 94: β = 1.760, learning rate = 4.74e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.204465
# 	D_KL = 0.011
# [BQRBM] epoch 95: β = 1.760, learning rate = 4.42e-03, β learning rate = 0.00e+00, epoch duration = 0:00:30.845301
# 	D_KL = 0.011
# [BQRBM] epoch 96: β = 1.760, learning rate = 4.12e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.084749
# 	D_KL = 0.011
# [BQRBM] epoch 97: β = 1.760, learning rate = 3.85e-03, β learning rate = 0.00e+00, epoch duration = 0:00:32.079993
# 	D_KL = 0.011
# [BQRBM] epoch 98: β = 1.760, learning rate = 3.59e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.371857
# 	D_KL = 0.012
# [BQRBM] epoch 99: β = 1.760, learning rate = 3.35e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.240103
# 	D_KL = 0.013
# [BQRBM] epoch 100: β = 1.760, learning rate = 3.13e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.597749
# 	D_KL = 0.012
# s = 0.45, β = 2.3996215366831106
# [BQRBM] epoch 1: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.357165
# 	D_KL = 0.076
# [BQRBM] epoch 2: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.921627
# 	D_KL = 0.078
# [BQRBM] epoch 3: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.296903
# 	D_KL = 0.064
# [BQRBM] epoch 4: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.422694
# 	D_KL = 0.053
# [BQRBM] epoch 5: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:29.785656
# 	D_KL = 0.052
# [BQRBM] epoch 6: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:30.087373
# 	D_KL = 0.037
# [BQRBM] epoch 7: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.927038
# 	D_KL = 0.059
# [BQRBM] epoch 8: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.460221
# 	D_KL = 0.064
# [BQRBM] epoch 9: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.724366
# 	D_KL = 0.036
# [BQRBM] epoch 10: β = 2.400, learning rate = 5.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.933835
# 	D_KL = 0.042
# [BQRBM] epoch 11: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:30.998688
# 	D_KL = 0.030
# [BQRBM] epoch 12: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.484040
# 	D_KL = 0.037
# [BQRBM] epoch 13: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.756841
# 	D_KL = 0.031
# [BQRBM] epoch 14: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.123631
# 	D_KL = 0.034
# [BQRBM] epoch 15: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.918980
# 	D_KL = 0.026
# [BQRBM] epoch 16: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.678858
# 	D_KL = 0.023
# [BQRBM] epoch 17: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.825169
# 	D_KL = 0.016
# [BQRBM] epoch 18: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.091213
# 	D_KL = 0.019
# [BQRBM] epoch 19: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.150075
# 	D_KL = 0.023
# [BQRBM] epoch 20: β = 2.400, learning rate = 2.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.358201
# 	D_KL = 0.021
# [BQRBM] epoch 21: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.020922
# 	D_KL = 0.016
# [BQRBM] epoch 22: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:30.983370
# 	D_KL = 0.017
# [BQRBM] epoch 23: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.505476
# 	D_KL = 0.033
# [BQRBM] epoch 24: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.487585
# 	D_KL = 0.018
# [BQRBM] epoch 25: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.214424
# 	D_KL = 0.020
# [BQRBM] epoch 26: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.092463
# 	D_KL = 0.012
# [BQRBM] epoch 27: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.539681
# 	D_KL = 0.016
# [BQRBM] epoch 28: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.985824
# 	D_KL = 0.018
# [BQRBM] epoch 29: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.705899
# 	D_KL = 0.012
# [BQRBM] epoch 30: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.590086
# 	D_KL = 0.014
# [BQRBM] epoch 31: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.053284
# 	D_KL = 0.013
# [BQRBM] epoch 32: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.326075
# 	D_KL = 0.019
# [BQRBM] epoch 33: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.086158
# 	D_KL = 0.015
# [BQRBM] epoch 34: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.497189
# 	D_KL = 0.017
# [BQRBM] epoch 35: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.090900
# 	D_KL = 0.016
# [BQRBM] epoch 36: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.294052
# 	D_KL = 0.016
# [BQRBM] epoch 37: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.272181
# 	D_KL = 0.015
# [BQRBM] epoch 38: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.131845
# 	D_KL = 0.019
# [BQRBM] epoch 39: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.597143
# 	D_KL = 0.015
# [BQRBM] epoch 40: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:30.897649
# 	D_KL = 0.018
# [BQRBM] epoch 41: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.422449
# 	D_KL = 0.015
# [BQRBM] epoch 42: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:32.008038
# 	D_KL = 0.013
# [BQRBM] epoch 43: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.004605
# 	D_KL = 0.015
# [BQRBM] epoch 44: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:30.717503
# 	D_KL = 0.019
# [BQRBM] epoch 45: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.816025
# 	D_KL = 0.022
# [BQRBM] epoch 46: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:30.875595
# 	D_KL = 0.017
# [BQRBM] epoch 47: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.204999
# 	D_KL = 0.016
# [BQRBM] epoch 48: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.118580
# 	D_KL = 0.016
# [BQRBM] epoch 49: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.498363
# 	D_KL = 0.018
# [BQRBM] epoch 50: β = 2.400, learning rate = 1.00e-01, β learning rate = 0.00e+00, epoch duration = 0:00:31.342855
# 	D_KL = 0.015
# [BQRBM] epoch 51: β = 2.400, learning rate = 9.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.760560
# 	D_KL = 0.013
# [BQRBM] epoch 52: β = 2.400, learning rate = 8.71e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.035815
# 	D_KL = 0.016
# [BQRBM] epoch 53: β = 2.400, learning rate = 8.12e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.495528
# 	D_KL = 0.016
# [BQRBM] epoch 54: β = 2.400, learning rate = 7.58e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.675304
# 	D_KL = 0.016
# [BQRBM] epoch 55: β = 2.400, learning rate = 7.07e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.751788
# 	D_KL = 0.016
# [BQRBM] epoch 56: β = 2.400, learning rate = 6.60e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.315297
# 	D_KL = 0.014
# [BQRBM] epoch 57: β = 2.400, learning rate = 6.16e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.629079
# 	D_KL = 0.015
# [BQRBM] epoch 58: β = 2.400, learning rate = 5.74e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.300597
# 	D_KL = 0.012
# [BQRBM] epoch 59: β = 2.400, learning rate = 5.36e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.816222
# 	D_KL = 0.012
# [BQRBM] epoch 60: β = 2.400, learning rate = 5.00e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.135185
# 	D_KL = 0.016
# [BQRBM] epoch 61: β = 2.400, learning rate = 4.67e-02, β learning rate = 0.00e+00, epoch duration = 0:00:29.774323
# 	D_KL = 0.012
# [BQRBM] epoch 62: β = 2.400, learning rate = 4.35e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.083060
# 	D_KL = 0.011
# [BQRBM] epoch 63: β = 2.400, learning rate = 4.06e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.492404
# 	D_KL = 0.012
# [BQRBM] epoch 64: β = 2.400, learning rate = 3.79e-02, β learning rate = 0.00e+00, epoch duration = 0:00:30.741662
# 	D_KL = 0.014
# [BQRBM] epoch 65: β = 2.400, learning rate = 3.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.366881
# 	D_KL = 0.015
# [BQRBM] epoch 66: β = 2.400, learning rate = 3.30e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.264222
# 	D_KL = 0.014
# [BQRBM] epoch 67: β = 2.400, learning rate = 3.08e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.141093
# 	D_KL = 0.011
# [BQRBM] epoch 68: β = 2.400, learning rate = 2.87e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.412561
# 	D_KL = 0.014
# [BQRBM] epoch 69: β = 2.400, learning rate = 2.68e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.040294
# 	D_KL = 0.013
# [BQRBM] epoch 70: β = 2.400, learning rate = 2.50e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.462008
# 	D_KL = 0.011
# [BQRBM] epoch 71: β = 2.400, learning rate = 2.33e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.926199
# 	D_KL = 0.014
# [BQRBM] epoch 72: β = 2.400, learning rate = 2.18e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.273222
# 	D_KL = 0.014
# [BQRBM] epoch 73: β = 2.400, learning rate = 2.03e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.335636
# 	D_KL = 0.013
# [BQRBM] epoch 74: β = 2.400, learning rate = 1.89e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.747240
# 	D_KL = 0.012
# [BQRBM] epoch 75: β = 2.400, learning rate = 1.77e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.661252
# 	D_KL = 0.012
# [BQRBM] epoch 76: β = 2.400, learning rate = 1.65e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.632227
# 	D_KL = 0.014
# [BQRBM] epoch 77: β = 2.400, learning rate = 1.54e-02, β learning rate = 0.00e+00, epoch duration = 0:00:32.013524
# 	D_KL = 0.012
# [BQRBM] epoch 78: β = 2.400, learning rate = 1.44e-02, β learning rate = 0.00e+00, epoch duration = 0:00:32.463612
# 	D_KL = 0.012
# [BQRBM] epoch 79: β = 2.400, learning rate = 1.34e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.854351
# 	D_KL = 0.010
# [BQRBM] epoch 80: β = 2.400, learning rate = 1.25e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.734542
# 	D_KL = 0.014
# [BQRBM] epoch 81: β = 2.400, learning rate = 1.17e-02, β learning rate = 0.00e+00, epoch duration = 0:00:32.030572
# 	D_KL = 0.012
# [BQRBM] epoch 82: β = 2.400, learning rate = 1.09e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.875945
# 	D_KL = 0.012
# [BQRBM] epoch 83: β = 2.400, learning rate = 1.02e-02, β learning rate = 0.00e+00, epoch duration = 0:00:31.213694
# 	D_KL = 0.016
# [BQRBM] epoch 84: β = 2.400, learning rate = 9.47e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.490689
# 	D_KL = 0.015
# [BQRBM] epoch 85: β = 2.400, learning rate = 8.84e-03, β learning rate = 0.00e+00, epoch duration = 0:00:32.045507
# 	D_KL = 0.012
# [BQRBM] epoch 86: β = 2.400, learning rate = 8.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.583363
# 	D_KL = 0.015
# [BQRBM] epoch 87: β = 2.400, learning rate = 7.69e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.560191
# 	D_KL = 0.013
# [BQRBM] epoch 88: β = 2.400, learning rate = 7.18e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.639754
# 	D_KL = 0.011
# [BQRBM] epoch 89: β = 2.400, learning rate = 6.70e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.835954
# 	D_KL = 0.012
# [BQRBM] epoch 90: β = 2.400, learning rate = 6.25e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.337758
# 	D_KL = 0.014
# [BQRBM] epoch 91: β = 2.400, learning rate = 5.83e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.722174
# 	D_KL = 0.014
# [BQRBM] epoch 92: β = 2.400, learning rate = 5.44e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.852180
# 	D_KL = 0.013
# [BQRBM] epoch 93: β = 2.400, learning rate = 5.08e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.662721
# 	D_KL = 0.012
# [BQRBM] epoch 94: β = 2.400, learning rate = 4.74e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.484282
# 	D_KL = 0.017
# [BQRBM] epoch 95: β = 2.400, learning rate = 4.42e-03, β learning rate = 0.00e+00, epoch duration = 0:00:32.119821
# 	D_KL = 0.011
# [BQRBM] epoch 96: β = 2.400, learning rate = 4.12e-03, β learning rate = 0.00e+00, epoch duration = 0:00:32.281137
# 	D_KL = 0.010
# [BQRBM] epoch 97: β = 2.400, learning rate = 3.85e-03, β learning rate = 0.00e+00, epoch duration = 0:00:32.415944
# 	D_KL = 0.015
# [BQRBM] epoch 98: β = 2.400, learning rate = 3.59e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.754174
# 	D_KL = 0.009
# [BQRBM] epoch 99: β = 2.400, learning rate = 3.35e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.523427
# 	D_KL = 0.011
# [BQRBM] epoch 100: β = 2.400, learning rate = 3.13e-03, β learning rate = 0.00e+00, epoch duration = 0:00:31.668142
# 	D_KL = 0.010
# time: 7h 59min 43s (started: 2022-01-31 21:19:26 +01:00)

# %%
model_paths = sorted(
    [
        f
        for f in (artifact_dir / "models").iterdir()
        if f.name.startswith("model_exact-s=")
    ]
)
models = [BQRBM.load(model_path) for model_path in model_paths]
# Out:
# time: 13.3 ms (started: 2022-01-31 17:26:45 +01:00)

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
import seaborn as sns

def smooth(x, k=10):
    x_out = np.zeros(len(x))
    for i in range(len(x)):
        x_out[i] = np.mean(x[i - min((k - 1, i)):i+1])
    return x_out

markers = ["o", "^", "v", "<", ">", "s", "p", "*", "P", "X", "+", "x"]
colors = [
    "tab:blue",
    "tab:orange",
    "tab:green",
    "tab:red",
    "tab:purple",
    "tab:brown",
    "tab:pink",
    "tab:gray",
    "tab:olive",
    "tab:cyan",
    "black",
    "gray",
]
# colors = sns.color_palette("magma", len(models))
s_betas = {s: beta for s, beta in zip(s_values, betas)}
for i, m in enumerate(models):
    dkls = [d["value"] for d in m.callback_outputs]
    print(m.anneal_params["s"], np.mean(dkls[-10:]))
    epochs = np.arange(1, len(dkls) + 1)
    ax.plot(
        epochs,
        smooth(dkls),
        label=fr"$s^* = {m.anneal_params['s']:.2f}$, $\beta_{{eff}} = {betas[::-1][i]:.2f}$",
        color=colors[i],
        marker=markers[i],
        markersize=8,
        markevery=3,
    )
ax.set_yticks(np.arange(0, 0.13, 0.02))
ax.set_ylim((0, 0.12))
ax.set_xlabel("Epoch")
ax.set_ylabel(r"$D_{KL}(p_{data} \ || \ p_{model})$ [10 Epoch Moving Average]")
ax.grid(True)
ax.legend()
plt.tight_layout()
plt.savefig(plot_dir / "dkl_exact_s_sweep.png")
